# %%
from __future__ import division
import random
import math
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing
pool_size = multiprocessing.cpu_count()

# %% [markdown]
# # Functions to Optimize

# %% [markdown]
# ## Sphere

# %%
def sphere(x):
    """
    Sphere function (sum of squares).
    :param x: Input vector.
    :return: Value of sphere function on x.
    """
    x = np.array(x)
    return np.sum(x**2)

# %%
sphere([0, 0, 0 ])
# Out:
# 0

# %%
x = np.linspace(-5.12, 5.12, 200)
y = np.array([sphere([xi]) for xi in x]) 


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Sphere Function Example Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Rosenbrock

# %%
def rosenbrock(x):
    """
    Implement Rosenbrock function.
    :param x: Input vector.
    :return: Value of Rosenbrock function on x.
    """
    x = np.array(x)
    return np.sum(100.0 * (x[1:] - x[:-1]**2)**2 + (1 - x[:-1])**2)

# %%
rosenbrock([1,1])
# Out:
# 0.0

# %%
# Plotting Rosenbrock Slice with y = 1
x = np.linspace(-5, 10, 200)
y = np.array([rosenbrock([xi, 1]) for xi in x]) 


plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('f(x, 1)')
plt.title('Rosenbrock Example: Slice with y = 1')
plt.grid(True)
plt.show()

# Using sympty to show global minima
import sympy as sp
x, y  = sp.symbols('x y')
f = 100 * (y - x**2)**2 + (1 - x)**2  # 2D Rosenbrock

# Computing derivatives
df_dx = sp.diff(f, x)
df_dy = sp.diff(f, y)

min_point = sp.solve([df_dx, df_dy], (x, y)) # Finding minima

# Printing minima
print("Minimum point:", min_point[0])
min_value = f.subs({x: min_point[0][0], y: min_point[0][1]})
print("Minimum value:", min_value)
# Out:
# Minimum point: (1, 1)
# Minimum value: 0

# %% [markdown]
# ## Rastigrin

# %%
def rastigrin(x):
    """
    Implement Rastigrin function.
    :param x: Input vector.
    :return: Value of Rastigrin function on x.
    """
    x = np.array(x)
    sum = np.sum (x**2 - 10 * np.cos(2*math.pi*x))
    
    return 10 * x.size + sum

# %%
rastigrin([0,0,0])
# Out:
# 0.0

# %%
x = np.linspace(-5.12, 5.12, 200)
y = np.array([rastigrin([xi]) for xi in x]) 


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Rastigrin Function Example Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ackley

# %%
def ackley(x):
    """
    Implement Ackley function.
    :param x: Input vector.
    :return: Value of Rastigrin function on x.
    """
    
    x = np.array(x)

    mean_squared_sumx = np.sqrt(np.sum(x**2) /x.size)
    mean_cos_sumx = np.sum(np.cos(2*np.pi*x) /x.size)

    ackley_sum = -20 * np.exp(-0.2 * mean_squared_sumx) - np.exp(mean_cos_sumx) + 20 + np.e
    
    return ackley_sum

# %%
ackley([0, 0, 0])
# Out:
# 4.440892098500626e-16

# %%
# Rounding because of floating point error

np.round(ackley([0, 0, 0]), 2)
# Out:
# 0.0

# %%
x = np.linspace(-32.768,32.768, 200)
y = np.array([ackley([xi]) for xi in x]) 


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Ackley Function Example Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# # Particle Swarm Optimization Code

# %%
import random
import numpy as np

# These classes has been adapted from the code given in Lab 5

class Particle:
    """
    A particle in a swarm.
    """
    
    def __init__(self, bounds, num_dim, rng = None):
        """
        Initialize a particle with random position and velocity, knowing bounds.
        
        :param bounds: List of bounds for each dimension.
        :param num_dim: Dimension
        """
        if rng is None:
            rng = np.random.RandomState()

        # sample positions uniformly in bounds
        self.position_i = [rng.uniform(b[0], b[1]) for b in bounds]

        # sample velocities in ~10–20% of range.
        #self.velocity_i = [random.uniform(-0.2*(b[1]-b[0]), 0.2*(b[1]-b[0])) for b in bounds]
        
        self.velocity_i = [
            rng.uniform(-r*(b[1]-b[0]), r*(b[1]-b[0])) 
            for b, r in zip(bounds, [rng.uniform(0.1, 0.2) for _ in bounds])
        ]


        

        # Define V_max to clamp velocities
        # Velocity clamp: ∣ 𝑣∣≤ 0.5 (upper − lower)
        self.V_max = [0.5 * (b[1] - b[0]) for b in bounds]

        
        self.num_dim = num_dim

        # best position individual
        self.pos_best_i = []

        # best error individual
        self.err_best_i=-1

        # error individual
        self.err_i=-1 
    

    
    def evaluate(self, function):
        """
        Evaluate a particle's current position, by calculating the value of its objective function.
        Update the particle's best position and error if the current position is better.

        :param function: Function to be optimized.
        """ 
        
        self.err_i = function(self.position_i)

        # check to see if the current position is an individual best
        if self.err_i < self.err_best_i or self.err_best_i==-1:
            self.pos_best_i=self.position_i
            self.err_best_i=self.err_i

    def update_velocity(self, pos_best_g, w, c1, c2, rng: np.random.RandomState):
        """
        Update particle's velocity based on constant inertia weight, cognitive constant, social constant, 
            personal best and global best. 

        :param pos_best_g: The global best position.
        :param w: Constant inertia weight (how much to weigh the previous velocity).
        :param c1: Cognitive constant.
        :param c2: Social constant.
        
        """ 
        

        for i in range(0,self.num_dim):
            r1 = rng.random()
            r2 = rng.random()

            vel_cognitive= c1* r1 *(self.pos_best_i[i] - self.position_i[i])
            vel_social= c2 * r2 * (pos_best_g[i] - self.position_i[i])
            
            velocity = w * self.velocity_i[i] + vel_cognitive + vel_social

            # Clamp Velocity using V_max
            if velocity > self.V_max[i]:
                velocity = self.V_max[i]
                
            if velocity < -self.V_max[i]:
                velocity = -self.V_max[i]
                
            self.velocity_i[i] = velocity

    def update_position(self, bounds):
        """
        Update particle's position based on current velocity and current position.

        :param bounds: List of bounds for each dimension.
        """ 
        
        for i in range(0, self.num_dim):
            
            self.position_i[i] = self.position_i[i] + self.velocity_i[i]

            # adjust maximum position if necessary
            if self.position_i[i ]> bounds[i][1]:
                self.position_i[i] = bounds[i][1]

            # adjust minimum position if necessary
            if self.position_i[i] < bounds[i][0]:
                self.position_i[i] = bounds[i][0]



class PSO():
    """
    Implement PSO (Particle Swarm Optimization) algorithm.
    """
    def __init__(self, num_dim, function, bounds, swarm_size, maxiter, w, c1, c2, early_stop_threshold, rng = None):
        """
        Initialize PSO and swarm of particles.

        :param num_dim: Number of dimensions.
        :param function: Function to be optimized.
        :param bounds: List of bounds for each particle dimension.
        :param swarm_size: Number of particles in swarm.
        :param maxiter: Maximum number of iterations.
        :param w: Constant inertia weight (how much to weigh the previous velocity).
        :param c1: Cognitive constant.
        :param c2: Social constant.
        :param early_stop_threshold: Stop when min of function below a tiny threshold.
        """
        
        self.num_dim = num_dim
        self.function = function
        self.swarm_size = swarm_size
        self.maxiter = maxiter
        
        self.w = w
        self.c1 = c1
        self.c2 = c2
        
        self.bounds = bounds
        if rng is None:
            rng = np.random.RandomState() 

        self.swarm = [Particle(bounds, num_dim, rng ) for _ in range(swarm_size)]
        
        self.pos_best_g = []
        self.err_best_g = -1

        self.early_stop_threshold = early_stop_threshold
        
        self.err_best_g_history = []
        
        self.iterations = 0
        
        self.pbest_history = [[] for _ in range(self.swarm_size)] 

    def run(self, rng: np.random.RandomState):
        """
        Run the PSO algorithm.
        """
       
        # Begin optimization loop
        i=0
        
        while i < self.maxiter:
            #print i,err_best_g
            # Cycle through particles in swarm and evaluate fitness
            for j in range(0, self.swarm_size):
                
                self.swarm[j].evaluate(self.function)
                self.pbest_history[j].append(self.swarm[j].err_best_i)
                
                # Determine if current particle is the best (globally)
                if self.swarm[j].err_i < self.err_best_g or self.err_best_g == -1:
                    self.pos_best_g = list(self.swarm[j].position_i)
                    self.err_best_g = float(self.swarm[j].err_i)
                    

            # Cycle through swarm and update velocities and position
            for j in range(0, self.swarm_size):
                self.swarm[j].update_velocity(self.pos_best_g, self.w, self.c1, self.c2, rng)
                self.swarm[j].update_position(self.bounds)
            
            i += 1
            self.err_best_g_history.append(self.err_best_g)
            if self.err_best_g < self.early_stop_threshold:
                break
                
        self.iterations = i

# %% [markdown]
# # Sphere Optimization

# %%
# Parameters for all dimensions of Sphere Optimization

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_sphere = 10**(-8) # early stopping threshold

# %% [markdown]
# ## Optimize Sphere in 2 dimensions

# %%
def run_pso(seed, num_dim, function, bounds, swarm_size, maxiter, w, c1, c2, early_stop_threshold):
    """
    Runs a PSO instance with a given random seed. 
    Used for parallel execution.

    :param pso: PSO instance.
    :param seed: Seed for random generator for ensuring reproducibility.
    
    :return: PSO instance after execution.
    """

    rng = np.random.RandomState(seed)
    pso = PSO(num_dim, function, bounds, swarm_size, maxiter, w, c1, c2, early_stop_threshold, rng)
    pso.run(rng)
    
    return pso

# %%
# PSO over 30 runs

n = 2 # Number of dimensions
max_iter = 300 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_sphere = [(-5.12, 5.12)]*n # Bounds for each dimension of particles


all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        
       
        res = pool.apply_async(run_pso, (run, n, sphere, bounds_sphere, swarm_size, max_iter, w, c1, c2, threshold_sphere,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_sphere)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 2D Sphere over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 2D Sphere over 30 runs:
# Mean: 5.6e-09
# Median: 6.6e-09
# Best: 7.6e-11
# Worst: 9.6e-09
# Std Dev: 3.2e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations
# Max iterations: 66
# Min iterations 39
# Mean iterations 54.833333333333336

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run' 

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         2.3e-10
# 2         7.6e-11
# 3         3.3e-09
# 4         9.3e-09
# 5         8.0e-09
# 6         6.6e-09
# 7         7.2e-09
# 8         3.2e-10
# 9         8.8e-09
# 10        9.6e-09
# 11        6.9e-09
# 12        9.5e-09
# 13        8.7e-09
# 14        7.9e-09
# 15        9.0e-09
# 16        1.2e-09
# 17        2.7e-09
# 18        8.9e-09
# 19        8.7e-09
# 20        2.0e-09
# 21        8.7e-09
# 22        5.2e-09
# 23        7.6e-09
# 24        2.6e-10
# 25        3.9e-09
# 26        1.2e-09
# 27        4.4e-09
# 28        5.4e-09
# 29        6.6e-09
# 30        5.9e-09
# Run                 1        2        3        4        5        6        7   \
# Final Fitness
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     1.2e-04    2.1e-03
# std      1.7e-04    3.6e-03
# min      2.5e-06    1.5e-05
# max      7.1e-04    1.7e-02

# %% [markdown]
# ### Parameter Study: Sphere Optimization in 2 Dimensions

# %%
from itertools import product

# Parameter changes
w_values = [0.7, 0.4, 0.9]
c1_values = [1.5, 1.0, 2.0]
c2_values = [1.5, 1.0, 2.0]


all_results = []

for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        
        for run in range(n_runs):
            
            
            
            res = pool.apply_async(run_pso, (run, n, sphere, bounds_sphere, swarm_size, max_iter, w_, c_1, c_2, threshold_sphere,))
            results.append((run, res))

        for run, result in results:
            # Collect results for each run
            result = result.get()
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })




df_param = pd.DataFrame(all_results)
pd.set_option('display.float_format', '{:.1e}'.format)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_sphere).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2  min  max    mean     std
# 0   0.4  1.0  1.0   17   24 2.1e+01 2.0e+00
# 1   0.4  1.0  1.5   19   28 2.3e+01 2.2e+00
# 2   0.4  1.0  2.0   22   29 2.6e+01 1.7e+00
# 3   0.4  1.5  1.0   17   24 2.1e+01 2.0e+00
# 4   0.4  1.5  1.5   19   28 2.3e+01 2.2e+00
# 5   0.4  1.5  2.0   22   29 2.6e+01 1.7e+00
# 6   0.4  2.0  1.0   17   24 2.1e+01 2.0e+00
# 7   0.4  2.0  1.5   19   28 2.3e+01 2.2e+00
# 8   0.4  2.0  2.0   22   29 2.6e+01 1.7e+00
# 9   0.7  1.0  1.0   38   62 5.3e+01 4.9e+00
# 10  0.7  1.0  1.5   39   66 5.5e+01 5.7e+00
# 11  0.7  1.0  2.0    5   79 6.0e+01 1.7e+01
# 12  0.7  1.5  1.0   38   62 5.3e+01 4.9e+00
# 13  0.7  1.5  1.5   39   66 5.5e+01 5.7e+00
# 14  0.7  1.5  2.0    5   79 6.0e+01 1.7e+01
# 15  0.7  2.0  1.0   38   62 5.3e+01 4.9e+00
# 16  0.7  2.0  1.5   39   66 5.5e+01 5.7e+00
# 17  0.7  2.0  2.0    5   79 6.0e+01 1.7e+01
# 18  0.9  1.0  1.0  150  275 2.1e+02 2.9e+01
# 19  0.9  1.0  1.5  204  300 2.8e+02 2.7e+01
# 20  0.9  1.0  2.0    5  300 1.2e+02 1.1e+02
# 21  0.9  1.5  1.0  150  275 2.1e+02 2.9e+01
# 22  0.9  1.5  1.5  204  300 2.8e+02 2.7e+01
# 23  0.9  1.5  2.0    5  300 1.2e+02 1.1e+02
# 24  0.9  2.0  1.0  150  275 2.1e+02 2.9e+01
# 25  0.9  2.0  1.5  204  300 2.8e+02 2.7e+01
# 26  0.9  2.0  2.0    5  300 1.2e+02 1.1e+02
# Summary Fits
#       w   c1   c2     mean      std      min      max
# 0   0.4  1.0  1.0  4.0e-09  2.7e-09  1.8e-10  1.0e-08
# 1   0.4  1.0  1.5  5.3e-09  3.0e-09  1.1e-10  1.0e-08
# 2   0.4  1.0  2.0  5.1e-09  2.9e-09  3.3e-10  9.5e-09
# 3   0.4  1.5  1.0  4.0e-09  2.7e-09  1.8e-10  1.0e-08
# 4   0.4  1.5  1.5  5.3e-09  3.0e-09  1.1e-10  1.0e-08
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0            46.7
# 9  0.7 1.0 1.0           100.0
# 10 0.7 1.0 1.5           100.0
# 11 0.7 1.0 2.0           100.0
# 12 0.7 1.5 1.0           100.0
# 13 0.7 1.5 1.5           100.0
# 14 0.7 1.5 2.0           100.0
# 15 0.7 2.0 1.0           100.0
# 16 0.7 2.0 1.5           100.0
# 17 0.7 2.0 2.0           100.0
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %% [markdown]
# ## Optimize Sphere in 30 dimensions

# %%
# PSO over 30 runs
n = 30 # Number of dimensions
max_iter = 1000 # Maximum Number of iterations
swarm_size = 50 # Swarm size
bounds_sphere = [(-5.12, 5.12)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_sphere = 10**(-8) # early stopping threshold   


all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, sphere, bounds_sphere, swarm_size, max_iter, w, c1, c2, threshold_sphere, ))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result) 

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_sphere)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Sphere over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Sphere over 30 runs:
# Mean: 2.6e+00
# Median: 7.5e-07
# Best: 1.4e-09
# Worst: 2.6e+01
# Std Dev: 7.9e+00
# Success Rate: 0.1 (10.0%)
# Number of iterations
# Max iterations: 1000
# Min iterations 706
# Mean iterations 985.8333333333334

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run' 

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 

df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         2.6e+01
# 2         9.9e-09
# 3         4.3e-07
# 4         3.8e-05
# 5         3.4e-08
# 6         2.0e-07
# 7         1.7e-08
# 8         9.4e-08
# 9         6.6e-04
# 10        5.6e-07
# 11        1.4e-09
# 12        3.1e-04
# 13        9.9e-08
# 14        2.8e-04
# 15        6.8e-05
# 16        6.8e-06
# 17        1.8e-07
# 18        2.7e-04
# 19        4.0e-08
# 20        1.1e-07
# 21        5.8e-06
# 22        1.9e-07
# 23        9.7e-09
# 24        1.3e-05
# 25        5.3e-08
# 26        6.1e-04
# 27        2.6e+01
# 28        2.6e+01
# 29        9.4e-07
# 30        1.6e-06
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  2.6e+01  9.9e-09  4.3e-07  3.8e-05  3.4e-08  2.0e-07  1.7e-08
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  9.4e-08  6.6e-04  5.6e-07  ...  5.8e-06  1.9e-07  9.7e-09
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  1.3e-05  5.3e-08  6.1e-04  2.6e+01  2.6e+01  9.4e-07  1.6e-06
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       1.2e-13    3.2e-13            2.6e+01     2.6e+01    2.6e+01
# 2       9.1e-11    3.3e-10            9.9e-09     1.0e-08    1.0e-08
# 3       1.3e-09    4.2e-09            4.3e-07     4.3e-07    4.4e-07
# 4       1.1e-10    3.0e-09            3.8e-05     3.8e-05    3.8e-05
# 5       1.9e-13    5.0e-13            3.4e-08     3.4e-08    3.4e-08
# 6       7.4e-12    2.0e-11            2.0e-07     2.0e-07    2.0e-07
# 7       4.9e-13    1.5e-12            1.7e-08     1.7e-08    1.7e-08
# 8       8.0e-12    3.9e-11            9.4e-08     9.4e-08    9.4e-08
# 9       6.7e-11    1.7e-10            6.6e-04     6.6e-04    6.6e-04
# 10      6.7e-11    1.4e-10            5.6e-07     5.6e-07    5.6e-07
# 11      1.6e-08    9.3e-08            1.4e-09     1.7e-08    9.5e-08
# 12      5.4e-10    2.6e-08            3.1e-04     3.1e-04    3.1e-04
# 13      6.7e-13    2.2e-12            9.9e-08     9.9e-08    9.9e-08
# 14      8.3e-10    1.8e-09            2.8e-04     2.8e-04    2.8e-04
# 15      4.3e-11    1.6e-10            6.8e-05     6.8e-05    6.8e-05
# 16      5.9e-11    3.7e-10            6.8e-06     6.8e-06    6.8e-06
# 17      4.3e-10    1.2e-09            1.8e-07     1.8e-07    1.8e-07
# 18      6.3e-09    1.3e-08            2.7e-04     2.7e-04    2.7e-04
# 19      4.1e-12    1.1e-11            4.0e-08     4.0e-08    4.0e-08
# 20      1.8e-12    6.6e-12            1.1e-07     1.1e-07    1.1e-07
# 21      1.3e-10    4.5e-10            5.8e-06     5.8e-06    5.8e-06
# 22      1.2e-13    2.6e-13            1.9e-07     1.9e-07    1.9e-07
# 23      4.1e-10    9.0e-10            9.7e-09     1.0e-08    1.1e-08
# 24      6.7e-11    1.4e-10            1.3e-05     1.3e-05    1.3e-05
# 25      2.7e-11    5.4e-11            5.3e-08     5.3e-08    5.3e-08
# 26      8.8e-11    2.3e-10            6.1e-04     6.1e-04    6.1e-04
# 27      3.8e-13    1.3e-12            2.6e+01     2.6e+01    2.6e+01
# 28      8.2e-13    2.6e-12            2.6e+01     2.6e+01    2.6e+01
# 29      1.3e-09    3.6e-09            9.4e-07     9.4e-07    9.4e-07
# 30      6.1e-14    1.8e-13            1.6e-06     1.6e-06    1.6e-06
#
#      Std PBest
# Run
# 1      6.5e-14
# 2      7.1e-11
# 3      8.7e-10
# 4      4.3e-10
# 5      1.2e-13
# 6      4.5e-12
# 7      3.1e-13
# 8      6.9e-12
# 9      3.5e-11
# 10     3.0e-11
# 11     1.6e-08
# 12     3.6e-09
# 13     4.5e-13
# 14     4.2e-10
# 15     2.9e-11
# 16     6.5e-11
# 17     2.6e-10
# 18     2.9e-09
# 19     2.6e-12
# 20     1.4e-12
# 21     8.5e-11
# 22     5.6e-14
# 23     2.0e-10
# 24     2.9e-11
# 25     1.1e-11
# 26     4.8e-11
# 27     2.6e-13
# 28     6.1e-13
# 29     8.4e-10
# 30     3.5e-14
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     9.3e-10    5.0e-09
# std      3.1e-09    1.7e-08
# min      6.1e-14    1.8e-13
# max      1.6e-08    9.3e-08

# %% [markdown]
# ### Parameter Study: Optimize Sphere in 30 dimensions

# %%
from itertools import product
import pandas as pd

# Parameter changes
w_values = [0.4, 0.7, 0.9]
c1_values = [1.0, 1.5, 2.0]
c2_values = [1.0, 1.5, 2.0]

all_results = []

for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        
        for run in range(n_runs):
            
            
            res = pool.apply_async(run_pso, (run, n, sphere, bounds_sphere, swarm_size, max_iter, w_, c_1, c_2, threshold_sphere, ))
            results.append((run, res))

        for run, result in results:
            # Collect results for each run
            result = result.get()
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })
            



df_param = pd.DataFrame(all_results)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_sphere).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2   min   max    mean     std
# 0   0.4  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 1   0.4  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 2   0.4  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 3   0.4  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 4   0.4  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 5   0.4  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 6   0.4  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 7   0.4  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 8   0.4  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# 9   0.7  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 10  0.7  1.0  1.5   706  1000 9.9e+02 5.5e+01
# 11  0.7  1.0  2.0   781  1000 9.6e+02 6.7e+01
# 12  0.7  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 13  0.7  1.5  1.5   706  1000 9.9e+02 5.5e+01
# 14  0.7  1.5  2.0   781  1000 9.6e+02 6.7e+01
# 15  0.7  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 16  0.7  2.0  1.5   706  1000 9.9e+02 5.5e+01
# 17  0.7  2.0  2.0   781  1000 9.6e+02 6.7e+01
# 18  0.9  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 19  0.9  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 20  0.9  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 21  0.9  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 22  0.9  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 23  0.9  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 24  0.9  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 25  0.9  2.0  1.5  1000  1000 1.0e+03 0.0e+00
#
0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0            30.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0            30.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %% [markdown]
# ## Optimize Rosenbrock in 10 dimensions

# %%
# Dimension: 10
n = 10 # Number of dimensions
max_iter = 500 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_rosenbrock = [(-5.0, 10.0)]*n

# Parameters for all dimensions

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rosenbrock = 10**(-8) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):



        res = pool.apply_async(run_pso, (run, n, rosenbrock, bounds_rosenbrock, swarm_size, max_iter, w, c1, c2, threshold_rosenbrock,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses < threshold_rosenbrock)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 10D Rosenbrock over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 3.7e+02
# Median: 4.6e+00
# Best: 9.9e-02
# Worst: 2.5e+03
# Std Dev: 8.4e+02
# Success Rate: 0.0 (0.0%)
# Number of iterations
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run'  

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         7.7e+00
# 2         3.0e+02
# 3         4.4e+00
# 4         3.8e+00
# 5         2.5e+03
# 6         4.1e+00
# 7         4.7e+00
# 8         3.0e+02
# 9         5.8e+00
# 10        4.8e+00
# 11        7.9e+00
# 12        8.5e+01
# 13        9.9e-02
# 14        3.0e+00
# 15        2.5e+03
# 16        2.6e+00
# 17        2.4e+00
# 18        3.8e+00
# 19        4.0e+00
# 20        3.9e+00
# 21        1.6e+00
# 22        5.3e+00
# 23        3.0e+02
# 24        6.9e-01
# 25        3.9e+00
# 26        4.5e+00
# 27        4.2e+00
# 28        2.5e+03
# 29        2.5e+03
# 30        7.1e+00
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  7.7e+00  3.0e+02  4.4e+00  3.8e+00  2.5e+03  4.1e+00  4.7e+00
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  3.0e+02  5.8e+00  4.8e+00  ...  1.6e+00  5.3e+00  3.0e+02
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  6.9e-01  3.9e+00  4.5e+00  4.2e+00  2.5e+03  2.5e+03  7.1e+00
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       1.0e-03    9.0e-03            7.7e+00     7.7e+00    7.7e+00
# 2       6.6e-07    6.0e-06            3.0e+02     3.0e+02    3.0e+02
# 3       9.4e-04    3.8e-03            4.4e+00     4.4e+00    4.4e+00
# 4       1.8e-03    6.3e-03            3.8e+00     3.8e+00    3.8e+00
# 5       9.3e-03    2.1e-02            2.5e+03     2.5e+03    2.5e+03
# 6       3.8e-04    1.1e-03            4.1e+00     4.1e+00    4.1e+00
# 7       1.1e-04    3.6e-04            4.7e+00     4.7e+00    4.7e+00
# 8       1.3e-09    4.2e-09            3.0e+02     3.0e+02    3.0e+02
# 9       1.7e-03    3.1e-03            5.8e+00     5.8e+00    5.8e+00
# 10      2.1e-03    5.9e-03            4.8e+00     4.8e+00    4.8e+00
# 11      1.9e-04    6.4e-04            7.9e+00     7.9e+00    7.9e+00
# 12      4.3e-14    1.4e-14            8.5e+01     8.5e+01    8.5e+01
# 13      2.0e-04    4.7e-04            9.9e-02     9.9e-02    9.9e-02
# 14      2.9e-03    9.0e-03            3.0e+00     3.0e+00    3.0e+00
# 15      2.5e-04    9.0e-04            2.5e+03     2.5e+03    2.5e+03
# 16      3.3e-03    8.3e-03            2.6e+00     2.6e+00    2.6e+00
# 17      1.6e-03    4.0e-03            2.4e+00     2.4e+00    2.4e+00
# 18      2.6e-03    7.7e-03            3.8e+00     3.8e+00    3.8e+00
# 19      2.8e-03    7.0e-03            4.0e+00     4.0e+00    4.0e+00
# 3  0.4 1.5 1.0             0.0
# 4  0.4 1.5 1.5             0.0
# 5  0.4 1.5 2.0             0.0
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0             0.0
# 9  0.7 1.0 1.0             0.0
# 10 0.7 1.0 1.5             0.0
# 11 0.7 1.0 2.0             0.0
# 12 0.7 1.5 1.0             0.0
# 13 0.7 1.5 1.5             0.0
# 14 0.7 1.5 2.0             0.0
# 15 0.7 2.0 1.0             0.0
# 16 0.7 2.0 1.5             0.0
# 17 0.7 2.0 2.0             0.0
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %%
# Dimension: 10
n = 10 # Number of dimensions
max_iter = 5000 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_rosenbrock = [(-5.0, 10.0)]*n

# Parameters for all dimensions

w = 0.7# constant inertia weight (how much to weigh the previous velocity)      
c1 = 2 # cognitive constant
c2 = 2 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rosenbrock = 10**(-8) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):



        res = pool.apply_async(run_pso, (run, n, rosenbrock, bounds_rosenbrock, swarm_size, max_iter, w, c1, c2, threshold_rosenbrock,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses < threshold_rosenbrock)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 10D Rosenbrock over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 4.6e+02
# Median: 4.0e+00
# Best: 9.6e-09
# Worst: 2.5e+03
# Std Dev: 8.5e+02
# Success Rate: 0.4 (40.0%)
# Number of iterations
# Max iterations: 5000
# Min iterations 3974
# Mean iterations 4708.333333333333

# %% [markdown]
# ## Optimize Rosenbrock in 30 dimensions

# %%
# Dimension: 30
n = 30 # Number of dimensions
swarm_size = 50 # Maximum Number of iterations
bounds_rosenbrock = [(-5.0, 10.0)]*n # Bounds for each dimension of particles
max_iter = 1000

# Parameters for all dimensions 

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rosenbrock = 10**(-8) # early stopping threshold


all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, rosenbrock, bounds_rosenbrock, swarm_size, max_iter, w, c1, c2, threshold_rosenbrock))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rosenbrock)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Rosenbrock over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Rosenbrock over 30 runs:
# Mean: 6.6e+04
# Median: 5.6e+04
# Best: 2.6e+01
# Worst: 2.2e+05
# Std Dev: 6.1e+04
# Success Rate: 0.0 (0.0%)
# Number of iterations
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run'  # Name the index column

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         1.1e+05
# 2         2.2e+05
# 3         5.6e+04
# 4         1.7e+05
# 5         9.4e+01
# 6         5.6e+04
# 7         5.5e+04
# 8         9.7e+01
# 9         2.9e+01
# 10        1.6e+05
# 11        5.6e+04
# 12        5.6e+04
# 13        7.5e+01
# 14        1.1e+05
# 15        8.4e+01
# 16        5.6e+04
# 17        5.6e+04
# 18        5.6e+04
# 19        5.6e+04
# 20        2.9e+01
# 21        5.7e+04
# 22        2.6e+01
# 23        5.6e+04
# 24        3.0e+01
# 25        1.8e+02
# 26        1.0e+05
# 27        8.1e+04
# 28        1.7e+05
# 29        1.7e+05
# 30        5.5e+04
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  1.1e+05  2.2e+05  5.6e+04  1.7e+05  9.4e+01  5.6e+04  5.5e+04
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  9.7e+01  2.9e+01  1.6e+05  ...  5.7e+04  2.6e+01  5.6e+04
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  3.0e+01  1.8e+02  1.0e+05  8.1e+04  1.7e+05  1.7e+05  5.5e+04
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       2.0e-04    4.8e-04            1.1e+05     1.1e+05    1.1e+05
# 2       4.4e-03    1.1e-02            2.2e+05     2.2e+05    2.2e+05
# 3       7.6e-05    5.6e-04            5.6e+04     5.6e+04    5.6e+04
# 4       1.6e-04    3.8e-04            1.7e+05     1.7e+05    1.7e+05
# 5       1.0e-02    2.4e-02            9.4e+01     9.4e+01    9.4e+01
# 6       1.1e-06    3.5e-06            5.6e+04     5.6e+04    5.6e+04
# 7       6.4e-06    1.6e-05            5.5e+04     5.5e+04    5.5e+04
w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 2 # cognitive constant
c2 = 2 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rosenbrock = 10**(-8) # early stopping threshold


all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, rosenbrock, bounds_rosenbrock, swarm_size, max_iter, w, c1, c2, threshold_rosenbrock))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rosenbrock)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Rosenbrock over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Rosenbrock over 30 runs:
# Mean: 1.0e+05
# Median: 9.3e+04
# Best: 1.0e-08
# Worst: 2.2e+05
# Std Dev: 6.1e+04
# Success Rate: 0.03333333333333333 (3.3333333333333335%)
# Number of iterations
# Max iterations: 30000
# Min iterations 17709
# Mean iterations 29590.3

# %% [markdown]
# # Rastigrin Optimization

# %%
w = 0.7      
c1 = 1.5
c2 = 1.5
n_runs = 30
threshold_rastigrin = 10**(-4)

# %% [markdown]
# ## Optimize Rastigrin in 2 dimensions

# %%
# Dimension: 2
# PSO over 30 runs

n = 2 # Number of dimensions
max_iter = 300 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_rastigrin = [(-5.12, 5.12)]*n # Bounds for each dimension of particles



all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run,n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w, c1, c2, threshold_rastigrin,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rastigrin)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 2D Rastigrin over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 2D Rastigrin over 30 runs:
# Mean: 3.0e-01
# Median: 7.8e-05
# Best: 4.6e-06
# Worst: 4.0e+00
# Std Dev: 7.8e-01
# Success Rate: 0.8 (80.0%)
# Number of iterations
# Max iterations: 300
# Min iterations 34
# Mean iterations 97.4

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run' 

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         3.3e-05
# 2         1.5e-05
# 3         8.8e-05
# 4         9.9e-01
# 5         9.3e-05
# 6         9.9e-01
# 7         9.8e-05
# 8         7.5e-05
# 9         1.2e-05
# 10        4.6e-06
# 11        6.3e-05
# 12        4.0e+00
# 13        1.3e-05
# 14        5.1e-06
# 15        2.8e-05
# 16        8.0e-05
# 17        5.0e-05
# 18        2.2e-05
# 19        7.1e-05
# 20        9.9e-01
# 21        9.9e-01
# 22        3.7e-05
# 23        8.8e-05
# 24        8.3e-05
# 25        8.5e-05
# 26        5.7e-05
# 27        9.9e-01
# 28        1.0e-04
# 29        2.9e-05
# 30        9.7e-05
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  3.3e-05  1.5e-05  8.8e-05  9.9e-01  9.3e-05  9.9e-01  9.8e-05
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  7.5e-05  1.2e-05  4.6e-06  ...  9.9e-01  3.7e-05  8.8e-05
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  8.3e-05  8.5e-05  5.7e-05  9.9e-01  1.0e-04  2.9e-05  9.7e-05
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last  pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       1.9e-01    2.2e+00            3.3e-05     1.9e-01    2.2e+00
# 2       9.3e-02    8.7e-01            1.5e-05     9.3e-02    8.7e-01
# 3       8.5e-02    7.6e-01            8.8e-05     8.5e-02    7.6e-01
# 4       0.0e+00    0.0e+00            9.9e-01     9.9e-01    9.9e-01
# 5       1.2e-01    3.1e+00            9.3e-05     1.2e-01    3.1e+00
# 6       0.0e+00    0.0e+00            9.9e-01     9.9e-01    9.9e-01
# 7       1.2e-01    1.0e+00            9.8e-05     1.2e-01    1.0e+00
# 8       3.0e-02    3.1e-01            7.5e-05     3.0e-02    3.1e-01
# 9       9.3e-02    1.2e+00            1.2e-05     9.3e-02    1.2e+00
# 10      2.3e-01    2.7e+00            4.6e-06     2.3e-01    2.7e+00
# 20  0.9  1.0  2.0  5.8e-05  2.1e-04  0.0e+00  1.1e-03
# 21  0.9  1.5  1.0  4.7e-05  2.8e-05  4.4e-06  9.6e-05
# 22  0.9  1.5  1.5  5.7e-05  2.9e-05  2.8e-06  9.9e-05
# 23  0.9  1.5  2.0  5.8e-05  2.1e-04  0.0e+00  1.1e-03
# 24  0.9  2.0  1.0  4.7e-05  2.8e-05  4.4e-06  9.6e-05
# 25  0.9  2.0  1.5  5.7e-05  2.9e-05  2.8e-06  9.9e-05
# 26  0.9  2.0  2.0  5.8e-05  2.1e-04  0.0e+00  1.1e-03
# Summary Success Rates
#      w  c1  c2  success_rate %
# 0  0.4 1.0 1.0            36.7
# 1  0.4 1.0 1.5            23.3
# 2  0.4 1.0 2.0            53.3
# 3  0.4 1.5 1.0            36.7
# 4  0.4 1.5 1.5            23.3
# 5  0.4 1.5 2.0            53.3
# 6  0.4 2.0 1.0            36.7
# 7  0.4 2.0 1.5            23.3
# 8  0.4 2.0 2.0            53.3
# 9  0.7 1.0 1.0            80.0
# 10 0.7 1.0 1.5            80.0
# 11 0.7 1.0 2.0            90.0
# 12 0.7 1.5 1.0            80.0
# 13 0.7 1.5 1.5            80.0
# 14 0.7 1.5 2.0            90.0
# 15 0.7 2.0 1.0            80.0
# 16 0.7 2.0 1.5            80.0
# 17 0.7 2.0 2.0            90.0
# 18 0.9 1.0 1.0           100.0
# 19 0.9 1.0 1.5           100.0
# 20 0.9 1.0 2.0            90.0
# 21 0.9 1.5 1.0           100.0
# 22 0.9 1.5 1.5           100.0
# 23 0.9 1.5 2.0            90.0
# 24 0.9 2.0 1.0           100.0
# 25 0.9 2.0 1.5           100.0
# 26 0.9 2.0 2.0            90.0

# %% [markdown]
# ## Optimize Rastigrin in 10 dimensions

# %%
# Dimension: 10
n = 10 # Number of dimensions
max_iter = 500 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_rastigrin = [(-5.12, 5.12)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rastigrin = 10**(-4) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w, c1, c2, threshold_rastigrin, ))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rastigrin)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 10D Rastigrin over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 10D Rastigrin over 30 runs:
# Mean: 3.1e+01
# Median: 2.8e+01
# Best: 8.0e+00
# Worst: 5.8e+01
# Std Dev: 1.5e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run'  # Name the index column

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         3.1e+01
# 2         8.0e+00
# 3         2.1e+01
# 4         2.2e+01
# 5         4.0e+01
# 6         2.0e+01
# 7         3.0e+01
# 8         1.2e+01
# 9         1.6e+01
# 10        5.1e+01
# 11        2.8e+01
# 12        2.3e+01
# 13        5.7e+01
# 14        5.4e+01
# 15        5.2e+01
# 16        3.4e+01
# 17        4.2e+01
# 18        1.8e+01
# 19        4.0e+01
# 20        3.6e+01
# 21        2.8e+01
# 22        1.8e+01
# 23        1.7e+01
# 24        9.0e+00
# 25        2.4e+01
# 26        5.8e+01
# 27        5.6e+01
# 28        4.1e+01
# 29        2.7e+01
# 30        1.8e+01
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  3.1e+01  8.0e+00  2.1e+01  2.2e+01  4.0e+01  2.0e+01  3.0e+01
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  1.2e+01  1.6e+01  5.1e+01  ...  2.8e+01  1.8e+01  1.7e+01
#
# Run                 24       25       26       27       28       29       30
# Final Fitness
# 11  0.7  1.0  2.0  3.3e+01  1.5e+01  9.0e+00  7.8e+01
# 12  0.7  1.5  1.0  3.3e+01  1.4e+01  1.3e+01  7.7e+01
# 13  0.7  1.5  1.5  3.1e+01  1.5e+01  8.0e+00  5.8e+01
# 14  0.7  1.5  2.0  3.3e+01  1.5e+01  9.0e+00  7.8e+01
# 15  0.7  2.0  1.0  3.3e+01  1.4e+01  1.3e+01  7.7e+01
# 16  0.7  2.0  1.5  3.1e+01  1.5e+01  8.0e+00  5.8e+01
# 17  0.7  2.0  2.0  3.3e+01  1.5e+01  9.0e+00  7.8e+01
# 18  0.9  1.0  1.0  2.6e+01  1.7e+01  6.0e+00  7.6e+01
# 19  0.9  1.0  1.5  3.1e+01  1.5e+01  1.2e+01  6.8e+01
# 20  0.9  1.0  2.0  5.7e+01  1.6e+01  2.0e+01  8.8e+01
# 21  0.9  1.5  1.0  2.6e+01  1.7e+01  6.0e+00  7.6e+01
# 22  0.9  1.5  1.5  3.1e+01  1.5e+01  1.2e+01  6.8e+01
# 23  0.9  1.5  2.0  5.7e+01  1.6e+01  2.0e+01  8.8e+01
# 24  0.9  2.0  1.0  2.6e+01  1.7e+01  6.0e+00  7.6e+01
# 25  0.9  2.0  1.5  3.1e+01  1.5e+01  1.2e+01  6.8e+01
# 26  0.9  2.0  2.0  5.7e+01  1.6e+01  2.0e+01  8.8e+01
# Summary Success Rates
#      w  c1  c2  success_rate %
# 0  0.4 1.0 1.0             0.0
# 1  0.4 1.0 1.5             0.0
# 2  0.4 1.0 2.0             0.0
# 3  0.4 1.5 1.0             0.0
# 4  0.4 1.5 1.5             0.0
# 5  0.4 1.5 2.0             0.0
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0             0.0
# 9  0.7 1.0 1.0             0.0
# 10 0.7 1.0 1.5             0.0
# 11 0.7 1.0 2.0             0.0
# 12 0.7 1.5 1.0             0.0
# 13 0.7 1.5 1.5             0.0
# 14 0.7 1.5 2.0             0.0
# 15 0.7 2.0 1.0             0.0
# 16 0.7 2.0 1.5             0.0
# 17 0.7 2.0 2.0             0.0
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %% [markdown]
# ### Test other parameters to find success rate > 0

# %%
# Dimension: 10
n = 10 # Number of dimensions
max_iter = 3000 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_rastigrin = [(-5.12, 5.12)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.9 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 3.0 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rastigrin = 10**(-4) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        random.seed(run)


        res = pool.apply_async(run_pso, (run, n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w, c1, c2, threshold_rastigrin,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rastigrin)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 10D Rastigrin over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 10D Rastigrin over 30 runs:
# Mean: 1.2e+01
# Median: 1.0e+00
# Best: 5.9e-05
# Worst: 5.8e+01
# Std Dev: 1.6e+01
# Success Rate: 0.1 (10.0%)
# Number of iterations
# Max iterations: 3000
# Min iterations 2461
# Mean iterations 2966.4

# %% [markdown]
# ## Optimize Rastigrin in 30 dimensions

# %%
# Dimension: 30
# Dimension: 10
n = 30 # Number of dimensions
max_iter = 1000 # Maximum Number of iterations
swarm_size = 50 # Swarm size
bounds_rastigrin = [(-5.12, 5.12)]*n # Bounds for each dimension of particles

# Parameters for all dimensions 

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rastigrin = 10**(-4) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):


        res = pool.apply_async(run_pso, (run, n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w, c1, c2, threshold_rastigrin,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rastigrin)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Rastigrin over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Rastigrin over 30 runs:
# Mean: 1.4e+02
# Median: 1.4e+02
# Best: 6.8e+01
# Worst: 2.5e+02
# Std Dev: 3.9e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = '
# 27      9.8e-09    3.0e-08            1.0e+02     1.0e+02    1.0e+02
# 28      3.7e-13    8.8e-13            1.7e+02     1.7e+02    1.7e+02
# 29      2.8e-14    0.0e+00            1.4e+02     1.4e+02    1.4e+02
# 30      4.6e-12    4.3e-11            1.4e+02     1.4e+02    1.4e+02
#
#      Std PBest
# Run
# 1      8.8e-12
# 2      3.3e-12
# 3      1.4e-09
# 4      8.2e-10
# 5      5.2e-07
# 6      1.7e-14
# 7      2.8e-14
# 8      6.7e-11
# 9      2.9e-10
# 10     3.0e-08
# 11     3.8e-13
# 12     5.9e-13
# 13     8.7e-13
# 14     8.7e-09
# 15     2.1e-14
# 16     9.2e-11
# 17     1.7e-11
# 18     1.6e-10
# 19     5.0e-11
# 20     8.5e-13
# 21     1.7e-11
# 22     2.8e-14
# 23     1.4e-10
# 24     3.6e-12
# 25     1.6e-11
# 26     2.0e-12
# 27     6.1e-09
# 28     2.2e-13
# 29     2.8e-14
# 30     6.1e-12
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     4.1e-08    9.3e-08
# std      2.2e-07    4.6e-07
# min      0.0e+00    0.0e+00
# max      1.2e-06    2.5e-06

# %% [markdown]
# ### Parameter Study: Optimize Rastigrin in 30 dimensions

# %%
from itertools import product

# Parameter changes

w_values = [0.4, 0.7, 0.9]
c1_values = [1.0, 1.5, 2.0]
c2_values = [1.0, 1.5, 2.0]

all_results = []
for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            
            res = pool.apply_async(run_pso, (run, n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w_, c_1, c_2, threshold_rastigrin,))
            results.append(res)

        for result in [res.get() for res in results]:
        # Collect results for each run
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })


df_param = pd.DataFrame(all_results)


df_param = pd.DataFrame(all_results)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_rastigrin).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2   min   max    mean     std
# 0   0.4  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 1   0.4  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 2   0.4  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 3   0.4  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 4   0.4  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 5   0.4  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 6   0.4  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 7   0.4  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 8   0.4  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# 9   0.7  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 10  0.7  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 11  0.7  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 12  0.7  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 13  0.7  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 14  0.7  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 15  0.7  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 16  0.7  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 17  0.7  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# 18  0.9  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 19  0.9  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 20  0.9  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 21  0.9  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 22  0.9  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 23  0.9  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 24  0.9  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 25  0.9  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 26  0.9  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# Summary Fits
#       w   c1   c2     mean      std      min      max
# 0   0.4  1.0  1.0  1.8e+02  3.2e+01  1.3e+02  2.6e+02
# 1   0.4  1.0  1.5  1.7e+02  2.6e+01  1.2e+02  2.3e+02
# 2   0.4  1.0  2.0  1.6e+02  3.0e+01  8.8e+01  2.1e+02
# 3   0.4  1.5  1.0  1.8e+02  3.2e+01  1.3e+02  2.6e+02
# 4   0.4  1.5  1.5  1.7e+02  2.6e+01  1.2e+02  2.3e+02
# 5   0.4  1.5  2.0  1.6e+02  3.0e+01  8.8e+01  2.1e+02
# 6   0.4  2.0  1.0  1.8e+02  3.2e+01  1.3e+02  2.6e+02
# 7   0.4  2.0  1.5  1.7e+02  2.6e+01  1.2e+02  2.3e+02
# 8   0.4  2.0  2.0  1.6e+02  3.0e+01  8.8e+01  2.1e+02
# 9   0.7  1.0  1.0  1.2e+02  3.3e+01  6.8e+01  1.8e+02
# 10  0.7  1.0  1.5  1.4e+02  4.0e+01  6.8e+01  2.5e+02
# 11  0.7  1.0  2.0  1.5e+02  3.5e+01  8.4e+01  2.2e+02
# 12  0.7  1.5  1.0  1.2e+02  3.3e+01  6.8e+01  1.8e+02
# 13  0.7  1.5  1.5  1.4e+02  4.0e+01  6.8e+01  2.5e+02
# 14  0.7  1.5  2.0  1.5e+02  3.5e+01  8.4e+01  2.2e+02
# 15  0.7  2.0  1.0  1.2e+02  3.3e+01  6.8e+01  1.8e+02
# 16  0.7  2.0  1.5  1.4e+02  4.0e+01  6.8e+01  2.5e+02
# 17  0.7  2.0  2.0  1.5e+02  3.5e+01  8.4e+01  2.2e+02
# 18  0.9  1.0  1.0  1.4e+02  3.4e+01  6.7e+01  2.0e+02
# 19  0.9  1.0  1.5  2.0e+02  3.0e+01  1.4e+02  2.8e+02
# 20  0.9  1.0  2.0  3.1e+02  2.7e+01  2.7e+02  3.7e+02
# 21  0.9  1.5  1.0  1.4e+02  3.4e+01  6.7e+01  2.0e+02
# 22  0.9  1.5  1.5  2.0e+02  3.0e+01  1.4e+02  2.8e+02
# 23  0.9  1.5  2.0  3.1e+02  2.7e+01  2.7e+02  3.7e+02
# 24  0.9  2.0  1.0  1.4e+02  3.4e+01  6.7e+01  2.0e+02
# 25  0.9  2.0  1.5  2.0e+02  3.0e+01  1.4e+02  2.8e+02
# 26  0.9  2.0  2.0  3.1e+02  2.7e+01  2.7e+02  3.7e+02
# Summary Success Rates
#      w  c1  c2  success_rate %
# 0  0.4 1.0 1.0             0.0
# 1  0.4 1.0 1.5             0.0
# 2  0.4 1.0 2.0             0.0
# 3  0.4 1.5 1.0             0.0
# 4  0.4 1.5 1.5             0.0
# 5  0.4 1.5 2.0             0.0
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0             0.0
# 9  0.7 1.0 1.0             0.0
# 10 0.7 1.0 1.5             0.0
# 11 0.7 1.0 2.0             0.0
# 12 0.7 1.5 1.0             0.0
# 13 0.7 1.5 1.5             0.0
# 14 0.7 1.5 2.0             0.0
# 15 0.7 2.0 1.0             0.0
# 16 0.7 2.0 1.5             0.0
# 17 0.7 2.0 2.0             0.0
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %%
# Dimension: 10
n = 30 # Number of dimensions
max_iter = 30000 # Maximum Number of iterations
swarm_size = 50 # Swarm size
bounds_rastigrin = [(-5.12, 5.12)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.9 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 2.0 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_rastigrin = 10**(-4) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        random.seed(run)


        res = pool.apply_async(run_pso, (run, n, rastigrin, bounds_rastigrin, swarm_size, max_iter, w, c1, c2, threshold_rastigrin,))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_rastigrin)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Rastigrin over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Rastigrin over 30 runs:
# Mean: 8.5e+01
# Median: 8.7e+01
# Best: 9.8e-05
# Worst: 1.7e+02
# Std Dev: 3.9e+01
# Success Rate: 0.03333333333333333 (3.3333333333333335%)
# Number of iterations
# Max iterations: 30000
# Min iterations 22114
# Mean iterations 29737.133333333335

# %% [markdown]
# # Ackley Optimization

# %%
w = 0.7      
c1 = 1.5
c2 = 1.5
n_runs = 30
threshold_ackley = 10**(-4)

# %% [markdown]
# ## Optimize Ackley in 2 Dimensions

# %%
# PSO over 30 runs

n = 2 # Number of dimensions
max_iter = 300 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_ackley= [(-32.768, 32.768)]*n # Bounds for each dimension of particles


all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w, c1, c2, threshold_ackley,))
        results.append(res)

    for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_ackley)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 2D Ackley over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 2D Ackley over 30 runs:
# Mean: 7.0e-05
# Median: 7.6e-05
# Best: 1.4e-05
# Worst: 9.9e-05
# Std Dev: 2.4e-05
# Success Rate: 1.0 (100.0%)
# Number of iterations
# Max iterations: 95
# Min iterations 62
# Mean iterations 79.56666666666666

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run' 

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1
# 29      9.1e-04    7.4e-03            9.0e-05     1.0e-03    7.5e-03
# 30      7.2e-02    1.2e+00            8.8e-05     7.2e-02    1.2e+00
#
#      Std PBest
# Run
# 1      7.6e-03
# 2      2.7e-02
# 3      2.4e-02
# 4      5.8e-03
# 5      1.5e-02
# 6      2.9e-03
# 7      3.5e-03
# 8      5.9e-03
# 9      1.1e-01
# 10     2.2e-02
# 11     4.0e-03
# 12     4.8e-03
# 13     1.1e-03
# 14     6.4e-03
# 15     2.6e-02
# 16     4.4e-03
# 17     2.6e-02
# 18     2.0e-02
# 19     1.1e-01
# 20     2.3e-02
# 21     4.3e-03
# 22     7.0e-03
# 23     1.7e-02
# 24     4.6e-03
# 25     9.0e-03
# 26     1.1e-02
# 27     2.1e-02
# 28     2.1e-02
# 29     1.5e-03
# 30     2.2e-01
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     1.0e-02    1.3e-01
# std      1.4e-02    2.5e-01
# min      9.1e-04    5.2e-03
# max      7.2e-02    1.2e+00

# %% [markdown]
# ### Parameter Study: Optimize Ackley in 2 Dimensions

# %%
from itertools import product

# Parameter changes
n = 2
w_values = [0.4, 0.7, 0.9]
c1_values = [1.0, 1.5, 2.0]
c2_values = [1.0, 1.5, 2.0]
n_runs = 30
threshold_ackley = 10**(-4)
bounds_ackley= [(-32.768, 32.768)]*n

all_results = []

for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
           
            res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w_, c_1, c_2, threshold_ackley, ))
            results.append((run, res))

        for run, result in results:
            # Collect results for each run
            result = result.get()
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })



df_param = pd.DataFrame(all_results)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_ackley).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2  min  max    mean     std
# 0   0.4  1.0  1.0   27   33 2.9e+01 1.6e+00
# 1   0.4  1.0  1.5   27   36 3.1e+01 2.3e+00
# 2   0.4  1.0  2.0   31   41 3.4e+01 2.3e+00
# 3   0.4  1.5  1.0   27   33 2.9e+01 1.6e+00
# 4   0.4  1.5  1.5   27   36 3.1e+01 2.3e+00
# 5   0.4  1.5  2.0   31   41 3.4e+01 2.3e+00
# 6   0.4  2.0  1.0   27   33 2.9e+01 1.6e+00
# 7   0.4  2.0  1.5   27   36 3.1e+01 2.3e+00
# 8   0.4  2.0  2.0   31   41 3.4e+01 2.3e+00
# 9   0.7  1.0  1.0   55   77 7.0e+01 6.2e+00
# 10  0.7  1.0  1.5   62   95 8.0e+01 6.5e+00
# 11  0.7  1.0  2.0    5  107 8.4e+01 2.4e+01
# 12  0.7  1.5  1.0   55   77 7.0e+01 6.2e+00
# 13  0.7  1.5  1.5   62   95 8.0e+01 6.5e+00
# 14  0.7  1.5  2.0    5  107 8.4e+01 2.4e+01
# 15  0.7  2.0  1.0   55   77 7.0e+01 6.2e+00
# 16  0.7  2.0  1.5   62   95 8.0e+01 6.5e+00
# 17  0.7  2.0  2.0    5  107 8.4e+01 2.4e+01
# 18  0.9  1.0  1.0  220  300 2.9e+02 2.0e+01
# 19  0.9  1.0  1.5  262  300 3.0e+02 6.9e+00
# 20  0.9  1.0  2.0    5  300 1.3e+02 1.1e+02
# 21  0.9  1.5  1.0  220  300 2.9e+02 2.0e+01
# 22  0.9  1.5  1.5  262  300 3.0e+02 6.9e+00
# 23  0.9  1.5  2.0    5  300 1.3e+02 1.1e+02
# 24  0.9  2.0  1.0  220  300 2.9e+02 2.0e+01
# 25  0.9  2.0  1.5  262  300 3.0e+02 6.9e+00
# 26  0.9  2.0  2.0    5  300 1.3e+02 1.1e+02
# Summary Fits
#       w   c1   c2     mean      std      min      max
# 0   0.4  1.0  1.0
# 15 0.7 2.0 1.0           100.0
# 16 0.7 2.0 1.5           100.0
# 17 0.7 2.0 2.0           100.0
# 18 0.9 1.0 1.0            43.3
# 19 0.9 1.0 1.5             3.3
# 20 0.9 1.0 2.0            76.7
# 21 0.9 1.5 1.0            43.3
# 22 0.9 1.5 1.5             3.3
# 23 0.9 1.5 2.0            76.7
# 24 0.9 2.0 1.0            43.3
# 25 0.9 2.0 1.5             3.3
# 26 0.9 2.0 2.0            76.7

# %% [markdown]
# ## Optimize Ackley in 10 dimensions

# %%
# Dimension: 10
n = 10 # Number of dimensions
max_iter = 500 # Maximum Number of iterations
swarm_size = 30 # Swarm size
bounds_ackley= [(-32.768, 32.768)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_ackley = 10**(-4) # early stopping threshold

all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
       
        res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w, c1, c2, threshold_ackley, ))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_ackley)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 10D Ackley over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 10D Ackley over 30 runs:
# Mean: 9.7e-01
# Median: 1.2e+00
# Best: 8.0e-05
# Worst: 2.3e+00
# Std Dev: 9.0e-01
# Success Rate: 0.43333333333333335 (43.333333333333336%)
# Number of iterations
# Max iterations: 500
# Min iterations 186
# Mean iterations 370.1666666666667

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run'  

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         1.6e+00
# 2         1.6e+00
# 3         2.0e+00
# 4         2.0e+00
# 5         8.6e-05
# 6         9.9e-05
# 7         8.6e-05
# 8         2.3e+00
# 9         9.1e-05
# 10        1.2e+00
# 11        9.9e-05
# 12        1.0e-04
# 13        2.0e+00
# 14        8.7e-05
# 15        1.6e+00
# 16        2.0e+00
# 17        9.9e-05
# 18        1.2e+00
# 19        1.2e+00
# 20        9.3e-05
# 21        2.0e+00
# 22        1.6e+00
# 23        2.3e+00
# 24        9.1e-05
# 25        9.5e-05
# 26        8.3e-05
# 27        1.6e+00
# 28        8.0e-05
# 29        1.2e+00
# 30        1.6e+00
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  1.6e+00  1.6e+00  2.0e+00  2.0e+00  8.6e-05  9.9e-05  8.6e-05
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  2.3e+00  9.1e-05  1.2e+00  ...  2.0e+00  1.6e+00  2.3e+00
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  9.1e-05  9.5e-05  8.3e-05  1.6e+00  8.0e-05  1.2e+00  1.6e+00
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       0.0e+00    0.0e+00            1.6e+00     1.6e+00    1.6e+00
# 2       0.0e+00    0.0e+00            1.6e+00     1.6e+00    1.6e+00
# 3       8.9e-16    0.0e+00            2.0e+00     2.0e+00    2.0e+00
# 4       8.9e-16    0.0e+00            2.0e+00     2.0e+00    2.0e+00
# 5       1.0e-04    2.6e-04            8.6e-05     1.9e-04    3.5e-04
# 6       8.7e-05    2.2e-04            9.9e-05     1.9e-04    3.2e-04
# 7       5.8e-05    1.8e-04            8.6e-05     1.4e-04    2.6e-04
# 8       4.4e-16    0.0e+00            2.3e+00     2.3e+00    2.3e+00
# 9       6.0e-05    2.0e-04            9.1e-05     1.5e-04    2.9e-04
# 10      0.0e+00    0.0e+00            1.2e+00     1.2e+00    1.2e+00
# 11      6.5e-05    2.0e-04            9.9e-05     1.6e-04    3.0e-04
# 12      1.2e-04    2.9e-04            1.0e-04     2.2e-04    3.9e-04
# 13      8.9e-16    0.0e+00            2.0e+00     2.0e+00    2.0e+00
# 14      8.0e-05    2.1e-04            8.7e-05     1.7e-04    3.0e-04
# 15      0.0e+00    0.0e+00            1.6e+00     1.6e+00    1.6e+00
# 16      8.9e-16    0.0e+00            2.0e+00     2.0e+00    2.0e+00
# 17      3.3e-05    1.2e-04            9.9e-05     1.3e-04    2.2e-04
# 18      0.0e+00    0.0e+00            1.2e+00     1.2e+00    1.2e+00
# 19      0.0e+00    0.0e+00            1.2e+00     1.2e+00    1.2e+00
# 20      5.5e-05    1.6e-04            9.3e-05     1.5e-04    2.5e-04
# 21      8.9e-16    0.0e+00            2.0e+00     2.0e+00    2.0e+00
# 22      0.0e+00    0.0e+00            1.6e+00     1.6e+00    1.6e+00
# 23      0.0e+00    0.0e+00            2.3e+00     2.3e+00    2.3e+00
# 24      7.6e-05    2.1e-04            9.1e-05     1.7e-04    3.0e-04
# 25      6.2e-05    1.2e-04            9.5e-05     1.6e-04    2.1e-04
# 26      6.3e-05    1.7e-04            8.3e-05     1.5e-04    2.5e-04
# 27      6.7e-16    0.0e+00            1.6e+00     1.6e+00    1.6e+00
# 28      4.6e-05    1.2e-04            8.0e-05     1.3e-04    2.0e-04
# 29      2.2e-16    0.0e+00            1.2e+00     1.2e+00    1.2e+00
# 30      6.7e-16    0.0e+00            1.6e+00     1.6e+00    1.6e+00
#
#      Std PBest
# Run
# 1      0.0e+00
# 2      0.0e+00
# 3      8.9e-16
# 4      8.9e-16
# 5      6.2e-05
# 6      5.0e-05
# 7      3.6e-05
# 8      4.4e-16
# 9      4.2e-05
# 10     0.0e+00
# 11     4.9e-05
# 12     6.9e-05
# 13     8.9e-16
# 14     5.0e-05
# 15     0.0e+00
# 16     8.9e-16
# 17     2.1e-05
# 18     0.0e+00
# 19     0.0e+00
# 20     2.9e-05
# 21     8.9e-16
# 22     0.0e+00
# 23     0.0e+00
# 24     4.7e-05
# 25     3.5e-05
# 26     3.7e-05
# 27     6.7e-16
# 28     2.4e-05
# 29     2.2e-16
# 30     6.7e-16
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     3.0e-05    8.2e-05
# std      3.9e-05    1.0e-04
# min      0.0e+00    0.0e+00
# max      1.2e-04    2.9e-04

# %% [markdown]
# ### Parameter Study: Optimize Ackley in 10 dimensions

# %%
from itertools import product

# Parameter changes

w_values = [0.4, 0.7, 0.9]
c1_values = [1.0, 1.5, 2.0]
c2_values = [1.0, 1.5, 2.0]

all_results = []

for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
           
            res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w_, c_1, c_2, threshold_ackley, ))
            results.append((run, res))

        for run, result in results:
            # Collect results for each run
            result = result.get()
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })


df_param = pd.DataFrame(all_results)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_ackley).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2  min  max    mean     std
# 0   0.4  1.0  1.0  500  500 5.0e+02 0.0e+00
# 1   0.4  1.0  1.5  500  500 5.0e+02 0.0e+00
# 2   0.4  1.0  2.0  500  500 5.0e+02 0.0e+00
# 3   0.4  1.5  1.0  500  500 5.0e+02 0.0e+00
# 4   0.4  1.5  1.5  500  500 5.0e+02 0.0e+00
# 5   0.4  1.5  2.0  500  500 5.0e+02 0.0e+00
# 6   0.4  2.0  1.0  500  500 5.0e+02 0.0e+00
# 7   0.4  2.0  1.5  500  500 5.0e+02 0.0e+00
# 8   0.4  2.0  2.0  500  500 5.0e+02 0.0e+00
# 21  0.9  1.5  1.0  6.6e-02  2.1e-01  9.5e-03  1.2e+00
# 22  0.9  1.5  1.5  2.9e+00  6.0e-01  1.8e+00  4.7e+00
# 23  0.9  1.5  2.0  8.3e+00  1.3e+00  5.7e+00  1.1e+01
# 24  0.9  2.0  1.0  6.6e-02  2.1e-01  9.5e-03  1.2e+00
# 25  0.9  2.0  1.5  2.9e+00  6.0e-01  1.8e+00  4.7e+00
# 26  0.9  2.0  2.0  8.3e+00  1.3e+00  5.7e+00  1.1e+01
# Summary Success Rates
#      w  c1  c2  success_rate %
# 0  0.4 1.0 1.0             0.0
# 1  0.4 1.0 1.5             0.0
# 2  0.4 1.0 2.0             0.0
# 3  0.4 1.5 1.0             0.0
# 4  0.4 1.5 1.5             0.0
# 5  0.4 1.5 2.0             0.0
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0             0.0
# 9  0.7 1.0 1.0            36.7
# 10 0.7 1.0 1.5            43.3
# 11 0.7 1.0 2.0            83.3
# 12 0.7 1.5 1.0            36.7
# 13 0.7 1.5 1.5            43.3
# 14 0.7 1.5 2.0            83.3
# 15 0.7 2.0 1.0            36.7
# 16 0.7 2.0 1.5            43.3
# 17 0.7 2.0 2.0            83.3
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %% [markdown]
# ## Optimize Ackley in 30 dimensions

# %%
# Dimension: 30
# Dimension: 10
n = 30 # Number of dimensions
max_iter = 1000 # Maximum Number of iterations
swarm_size = 50 # Swarm size
bounds_ackley= [(-32.768, 32.768)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.7 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 1.5 # cognitive constant
c2 = 1.5 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_ackley = 10**(-4) # early stopping threshold
all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w, c1, c2, threshold_ackley, ))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_ackley)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Ackley over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 8.0e+00
# Median: 6.7e+00
# Best: 2.6e+00
# Worst: 1.8e+01
# Std Dev: 4.6e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %%
# BoxPlot to see distribution over 30 runs
plt.boxplot(final_fitnesses)
plt.ylabel('Final Fitness')
plt.title('30-run Distribution')
plt.show()


# Create Table with Final Fitness for each Run
import pandas as pd
from tabulate import tabulate

df = pd.DataFrame({
    'Final Fitness': final_fitnesses }, index=range(1, len(final_fitnesses)+1)) 


df.index.name = 'Run'  

df_display = df.copy()
df_display['Final Fitness'] = df_display['Final Fitness'].apply(lambda x: f"{x:.1e}") 


df_transposed = df_display.T 

# Display table of fitnesses
display(df_display)

# Display transposed table of fitnesses
display(df_transposed)
# Out:
#     Final Fitness
# Run
# 1         4.0e+00
# 2         2.9e+00
# 3         9.6e+00
# 4         4.1e+00
# 5         4.9e+00
# 6         5.4e+00
# 7         7.4e+00
# 8         1.7e+01
# 9         5.3e+00
# 10        1.8e+01
# 11        4.9e+00
# 12        3.3e+00
# 13        8.0e+00
# 14        1.7e+01
# 15        6.0e+00
# 16        7.9e+00
# 17        4.0e+00
# 18        5.0e+00
# 19        1.5e+01
# 20        7.4e+00
# 21        6.0e+00
# 22        1.5e+01
# 23        5.1e+00
# 24        7.7e+00
# 25        2.6e+00
# 26        2.7e+00
# 27        9.1e+00
# 28        1.1e+01
# 29        1.6e+01
# 30        7.4e+00
# Run                 1        2        3        4        5        6        7   \
# Final Fitness  4.0e+00  2.9e+00  9.6e+00  4.1e+00  4.9e+00  5.4e+00  7.4e+00
#
# Run                 8        9        10  ...       21       22       23  \
# Final Fitness  1.7e+01  5.3e+00  1.8e+01  ...  6.0e+00  1.5e+01  5.1e+00
#
# Run                 24       25       26       27       28       29       30
# Final Fitness  7.7e+00  2.6e+00  2.7e+00  9.1e+00  1.1e+01  1.6e+01  7.4e+00
#
# [1 rows x 30 columns]

# %%
import numpy as np

final_stats = []

# For each run, compare personal bests and global best in last iteration
for run_idx, run in enumerate(all_runs):
    pbests = run['pbest_history'] # Personal Bests over iterations
    gbests = run['fitness_history'] # Global Bests
   
    
    final_pbests = [pbest[-1] for pbest in pbests]  # Take last pbests
    final_gbest = gbests[-1] # Take final global best
    
    # Compute statistics
    mean_pbest = np.mean(final_pbests)
    std_pbest  = np.std(final_pbests)
    max_pbest  = np.max(final_pbests)
    
    # Compare to global
    diff_mean  = mean_pbest - final_gbest
    diff_max   = max_pbest  - final_gbest
    
    final_stats.append({
        "Run": run_idx + 1,
        "Mean-GBest": diff_mean,
        "Max-GBest": diff_max,
        
        "Final Global Best": final_gbest,
        "Mean PBest": mean_pbest,
        "Max PBest": max_pbest,
        "Std PBest": std_pbest,
    })

import pandas as pd

df_stats = pd.DataFrame(final_stats).set_index("Run")
pd.set_option('display.float_format', '{:.1e}'.format)
print("Final Iteration Personal and Global Bests")
display(df_stats)

summary = df_stats[["Mean-GBest", "Max-GBest"]].agg(['mean', 'std', 'min', 'max'])

print("\nSummary Across All Runs:")
display(summary)
# Out:
# Final Iteration Personal and Global Bests
#      Mean-GBest  Max-GBest  Final Global Best  Mean PBest  Max PBest  \
# Run
# 1       5.2e-11    4.1e-10            4.0e+00     4.0e+00    4.0e+00
# 2       6.6e-09    1.9e-08            2.9e+00     2.9e+00    2.9e+00
# 3       4.2e-12    1.3e-11            9.6e+00     9.6e+00    9.6e+00
# 4       1.2e-11    4.4e-11            4.1e+00     4.1e+00    4.1e+00
# 5       3.8e-12    1.0e-11            4.9e+00     4.9e+00    4.9e+00
# 6       1.8e-10    4.2e-10            5.4e+00     5.4e+00    5.4e+00
# 7       1.2e-11    2.9e-11            7.4e+00     7.4e+00    7.4e+00
# 8       2.6e-12    1.1e-11            1.7e+01     1.7e+01    1.7e+01
# 9       2.7e-13    9.2e-13            5.3e+00     5.3e+00    5.3e+00
# 10      5.0e-13    2.0e-12            1.8e+01     1.8e+01    1.8e+01
# 11      6.8e-12    1.6e-11            4.9e+00     4.9e+00    4.9e+00
# 12      1.6e-12    5.6e-12            3.3e+00     3.3e+00    3.3e+00
# 13      3.8e-12    1.1e-11            8.0e+00     8.0e+00    8.0e+00
# 14      3.1e-11    6.8e-11            1.7e+01     1.7e+01    1.7e+01
# 15      1.4e-09    5.6e-09            6.0e+00     6.0e+00    6.0e+00
# 16      1.1e-11    3.1e-11            7.9e+00     7.9e+00    7.9e+00
# 17      3.0e-10    1.1e-09            4.0e+00     4.0e+00    4.0e+00
# 18      6.8e-10    1.4e-09            5.0e+00     5.0e+00    5.0e+00
# 19      1.3e-12    1.1e-11            1.5e+01     1.5e+01    1.5e+01
# 20      3.8e-03    7.4e-03            7.4e+00     7.4e+00    7.4e+00
# 21      3.2e-10    6.7e-10            6.0e+00     6.0e+00    6.0e+00
# 22      1.4e-10    3.3e-10            1.5e+01     1.5e+01    1.5e+01
# 23      5.2e-09    1.3e-08            5.1e+00     5.1e+00    5.1e+00
# 24      5.2e-11    1.2e-10            7.7e+00     7.7e+00    7.7e+00
# 25      6.9e-13    2.2e-12            2.6e+00     2.6e+00    2.6e+00
# 26      1.6e-10    8.3e-10            2.7e+00     2.7e+00    2.7e+00
# 27      3.8e-11    7.7e-11            9.1e+00     9.1e+00    9.1e+00
# 28      4.9e-12    1.7e-11            1.1e+01     1.1e+01    1.1e+01
# 29      4.6e-12    9.2e-12            1.6e+01     1.6e+01    1.6e+01
# 30      1.0e-12    3.7e-12            7.4e+00     7.4e+00    7.4e+00
#
#      Std PBest
# Run
# 1      8.6e-11
# 2      4.3e-09
# 3      3.1e-12
# 4      8.8e-12
# 5      2.2e-12
# 6      9.0e-11
# 7      5.9e-12
# 8      2.3e-12
# 9      1.7e-13
# 10     3.6e-13
# 11     2.9e-12
# 12     9.9e-13
# 13     2.4e-12
# 14     1.3e-11
# 15     1.3e-09
# 16     6.3e-12
# 17     2.2e-10
# 18     4.0e-10
# 19     1.7e-12
# 20     1.5e-03
# 21     1.6e-10
# 22     6.1e-11
# 23     3.5e-09
# 24     2.6e-11
# 25     4.9e-13
# 26     1.7e-10
# 27     1.8e-11
# 28     3.8e-12
# 29     2.3e-12
# 30     6.4e-13
# Summary Across All Runs:
#       Mean-GBest  Max-GBest
# mean     1.3e-04    2.5e-04
# std      7.0e-04    1.3e-03
# min      2.7e-13    9.2e-13
# max      3.8e-03    7.4e-03

# %% [markdown]
# ### Parameter Study: Optimize Ackley in 30 dimensions

# %%
from itertools import product

# Parameter changes

w_values = [0.4, 0.7, 0.9]
c1_values = [1.0, 1.5, 2.0]
c2_values = [1.0, 1.5, 2.0]

all_results = []

for w_, c_1, c_2 in product(w_values, c1_values, c2_values):
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            
            res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w_, c_1, c_2, threshold_ackley, ))
            results.append((run, res))

        for run, result in results:
            # Collect results for each run
            result = result.get()
            all_results.append({
                    'w': w_,
                    'c1': c_1,
                    'c2': c_2,
                    'run': run + 1,
                    'final_fitness': result.err_best_g,
                    'iterations': result.iterations,
                    'best_position': result.pos_best_g,
                    'evaluations': result.iterations * swarm_size,
                })


df_param = pd.DataFrame(all_results)

# Iterations
summary_iterations = (
    df_param
    .groupby(['w', 'c1', 'c2'])['iterations']
    .agg(['min', 'max', 'mean', 'std'])
    .reset_index()
)
summary_iterations['w']   = summary_iterations['w'].apply(lambda x: f"{x:.1f}")
summary_iterations['c1']  = summary_iterations['c1'].apply(lambda x: f"{x:.1f}")
summary_iterations['c2']  = summary_iterations['c2'].apply(lambda x: f"{x:.1f}")
print("Summary Iterations")
display(summary_iterations)

# Final fitnesses
summary_fit = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .agg(['mean', 'std', 'min', 'max'])
    .reset_index()
)
summary_fit['w']   = summary_fit['w'].apply(lambda x: f"{x:.1f}")
summary_fit['c1']  = summary_fit['c1'].apply(lambda x: f"{x:.1f}")
summary_fit['c2']  = summary_fit['c2'].apply(lambda x: f"{x:.1f}")
summary_fit[['mean', 'std', 'min', 'max']] = summary_fit[['mean', 'std', 'min', 'max']].apply(lambda col: col.map(lambda x: f"{x:.1e}"))
print("Summary Fits")
display(summary_fit)

summary_success = (
    df_param
    .groupby(['w', 'c1', 'c2'])['final_fitness']
    .apply(lambda x: (x <= threshold_ackley).sum() / len(x) * 100)
    .reset_index(name = 'success_rate %')
)
print("Summary Success Rates")
with pd.option_context('display.float_format', '{:.1f}'.format):
    display(summary_success)
# Out:
# Summary Iterations
#       w   c1   c2   min   max    mean     std
# 0   0.4  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 1   0.4  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 2   0.4  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 3   0.4  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 4   0.4  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 5   0.4  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 6   0.4  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 7   0.4  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 8   0.4  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# 9   0.7  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 10  0.7  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 11  0.7  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 12  0.7  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 13  0.7  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 14  0.7  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 15  0.7  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 16  0.7  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 17  0.7  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# 18  0.9  1.0  1.0  1000  1000 1.0e+03 0.0e+00
# 19  0.9  1.0  1.5  1000  1000 1.0e+03 0.0e+00
# 20  0.9  1.0  2.0  1000  1000 1.0e+03 0.0e+00
# 21  0.9  1.5  1.0  1000  1000 1.0e+03 0.0e+00
# 22  0.9  1.5  1.5  1000  1000 1.0e+03 0.0e+00
# 23  0.9  1.5  2.0  1000  1000 1.0e+03 0.0e+00
# 24  0.9  2.0  1.0  1000  1000 1.0e+03 0.0e+00
# 25  0.9  2.0  1.5  1000  1000 1.0e+03 0.0e+00
# 26  0.9  2.0  2.0  1000  1000 1.0e+03 0.0e+00
# Summary Fits
#       w   c1   c2     mean      std      min      max
# 0   0.4  1.0  1.0  1.7e+01  1.1e+00  1.4e+01  1.8e+01
# 1   0.4  1.0  1.5  1.6e+01  1.6e+00  1.3e+01  1.9e+01
# 2   0.4  1.0  2.0  1.5e+01  2.0e+00  1.0e+01  1.8e+01
# 3   0.4  1.5  1.0  1.7e+01  1.1e+00  1.4e+01  1.8e+01
# 4   0.4  1.5  1.5  1.6e+01  1.6e+00  1.3e+01  1.9e+01
# 5   0.4  1.5  2.0  1.5e+01  2.0e+00  1.0e+01  1.8e+01
# 6   0.4  2.0  1.0  1.7e+01  1.1e+00  1.4e+01  1.8e+01
# 7   0.4  2.0  1.5  1.6e+01  1.6e+00  1.3e+01  1.9e+01
# 8   0.4  2.0  2.0  1.5e+01  2.0e+00  1.0e+01  1.8e+01
# 9   0.7  1.0  1.0  1.1e+01  3.9e+00  4.3e+00  1.7e+01
# 10  0.7  1.0  1.5  8.0e+00  4.7e+00  2.6e+00  1.8e+01
# 11  0.7  1.0  2.0  9.7e+00  6.8e+00  1.5e+00  1.8e+01
# 12  0.7  1.5  1.0  1.1e+01  3.9e+00  4.3e+00  1.7e+01
# 13  0.7  1.5  1.5  8.0e+00  4.7e+00  2.6e+00  1.8e+01
# 14  0.7  1.5  2.0  9.7e+00  6.8e+00  1.5e+00  1.8e+01
# 15  0.7  2.0  1.0  1.1e+01  3.9e+00  4.3e+00  1.7e+01
# 16  0.7  2.0  1.5  8.0e+00  4.7e+00  2.6e+00  1.8e+01
# 17  0.7  2.0  2.0  9.7e+00  6.8e+00  1.5e+00  1.8e+01
# 18  0.9  1.0  1.0  4.7e+00  5.9e+00  3.2e-01  1.7e+01
# 19  0.9  1.0  1.5  1.2e+01  3.3e+00  7.0e+00  1.7e+01
# 20  0.9  1.0  2.0  1.8e+01  1.1e+00  1.6e+01  2.0e+01
# 21  0.9  1.5  1.0  4.7e+00  5.9e+00  3.2e-01  1.7e+01
# 22  0.9  1.5  1.5  1.2e+01  3.3e+00  7.0e+00  1.7e+01
# 23  0.9  1.5  2.0  1.8e+01  1.1e+00  1.6e+01  2.0e+01
# 24  0.9  2.0  1.0  4.7e+00  5.9e+00  3.2e-01  1.7e+01
# 25  0.9  2.0  1.5  1.2e+01  3.3e+00  7.0e+00  1.7e+01
# 26  0.9  2.0  2.0  1.8e+01  1.1e+00  1.6e+01  2.0e+01
# Summary Success Rates
#      w  c1  c2  success_rate %
# 0  0.4 1.0 1.0             0.0
# 1  0.4 1.0 1.5             0.0
# 2  0.4 1.0 2.0             0.0
# 3  0.4 1.5 1.0             0.0
# 4  0.4 1.5 1.5             0.0
# 5  0.4 1.5 2.0             0.0
# 6  0.4 2.0 1.0             0.0
# 7  0.4 2.0 1.5             0.0
# 8  0.4 2.0 2.0             0.0
# 9  0.7 1.0 1.0             0.0
# 10 0.7 1.0 1.5             0.0
# 11 0.7 1.0 2.0             0.0
# 12 0.7 1.5 1.0             0.0
# 13 0.7 1.5 1.5             0.0
# 14 0.7 1.5 2.0             0.0
# 15 0.7 2.0 1.0             0.0
# 16 0.7 2.0 1.5             0.0
# 17 0.7 2.0 2.0             0.0
# 18 0.9 1.0 1.0             0.0
# 19 0.9 1.0 1.5             0.0
# 20 0.9 1.0 2.0             0.0
# 21 0.9 1.5 1.0             0.0
# 22 0.9 1.5 1.5             0.0
# 23 0.9 1.5 2.0             0.0
# 24 0.9 2.0 1.0             0.0
# 25 0.9 2.0 1.5             0.0
# 26 0.9 2.0 2.0             0.0

# %%
# Dimension: 30
# Dimension: 10
n = 30 # Number of dimensions
max_iter = 30000 # Maximum Number of iterations
swarm_size = 50 # Swarm size
bounds_ackley= [(-32.768, 32.768)]*n # Bounds for each dimension of particles

# Parameters for all dimensions of Sphere Optimization

w = 0.9 # constant inertia weight (how much to weigh the previous velocity)      
c1 = 2.0 # cognitive constant
c2 = 1.0 # social constant

n_runs = 30 # aggregate results over 30 runs

threshold_ackley = 10**(-4) # early stopping threshold
all_runs = []
results = []
with multiprocessing.Pool(processes=pool_size) as pool:
    for run in range(n_runs):
        
        res = pool.apply_async(run_pso, (run, n, ackley, bounds_ackley, swarm_size, max_iter, w, c1, c2, threshold_ackley, ))
        results.append(res)

    for result in [res.get() for res in results]:
        run_result = {
            'final_fitness': result.err_best_g,
            'best_position': result.pos_best_g,
            'iterations': result.iterations,
            'fitness_history': result.err_best_g_history,
            'evaluations': result.iterations * swarm_size,
            'pbest_history': result.pbest_history
        }
        all_runs.append(run_result)

# Compute Statistics for Final Fitnesses
final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
best_final_fitness = np.min(final_fitnesses) # Best final fitness
worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
success_rate_final_fitness = np.sum(final_fitnesses <= threshold_ackley)/n_runs # Success rate: Number of sucessful runs/ no. of runs

# Print Statistics
print("Final fitness stats for 30D Ackley over 30 runs:")
print(f"Mean: {mean_final_fitness:.1e}")
print(f"Median: {median_final_fitness:.1e}")
print(f"Best: {best_final_fitness:.1e}")
print(f"Worst: {worst_final_fitness:.1e}")
print(f"Std Dev: {std_dev_final_fitness:.1e}")
print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")

# Convergence Plot for All Runs - Fitness history of all runs
# Since early stopping is added, no. of iterations can vary between runs
# Therefore plot each run individually
for run in all_runs:
    plt.plot(run['fitness_history'], alpha=0.3)
plt.xlabel('Iteration')
plt.ylabel('Global Best Fitness')
plt.title('Convergence Plot (30 runs)')
plt.show()

# Iterations
no_iterations =  np.array([run['iterations'] for run in all_runs]) 
min_iterations = np.min(no_iterations) # Min iterations
max_iterations = np.max(no_iterations) # Max iterations
mean_iterations = np.mean(no_iterations) # Mean iterations

print("Number of iterations")
print("Max iterations:", max_iterations)
print("Min iterations", min_iterations)
print("Mean iterations", mean_iterations)
# Out:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 3.9e+00
# Median: 1.0e-04
# Best: 8.8e-05
# Worst: 1.7e+01
# Std Dev: 6.2e+00
# Success Rate: 0.5333333333333333 (53.333333333333336%)
# Number of iterations
# Max iterations: 30000
# Min iterations 2428
# Mean iterations 15532.966666666667

# %% [markdown]
# # Hybrid Local Search

# %%
# Reference:
# "A Particle Swarm Optimization-Nelder Mead Hybrid Algorithm for Balanced Exploration and Exploitation 
# in Multidimensional Search Space", January 2006, 
# Proceedings of the 2006 International Conference on Artificial Intelligence (ICAI 2006), 
# Las Vegas, Nevada, USA, Volume 2, Source: DBLP





import random
import numpy as np

class Particle_ND:
    """
    A particle in a swarm.
    """
    
    def __init__(self, bounds, num_dim, rng = None):
        """
        Initialize a particle with random position and velocity, knowing bounds.
        
        :param bounds: List of bounds for each dimension.
        :param num_dim: Dimension
        """
        if rng is None:
            rng = np.random.RandomState()

        # sample positions uniformly in bounds
        self.position_i = [rng.uniform(b[0], b[1]) for b in bounds]

        # sample velocities in ~10–20% of range.
        #self.velocity_i = [random.uniform(-0.2*(b[1]-b[0]), 0.2*(b[1]-b[0])) for b in bounds]
        
        self.velocity_i = [
            rng.uniform(-r*(b[1]-b[0]), r*(b[1]-b[0])) 
            for b, r in zip(bounds, [rng.uniform(0.1, 0.2) for _ in bounds])
        ]


        

        # Define V_max to clamp velocities
        # Velocity clamp: ∣ 𝑣∣≤ 0.5 (upper − lower)
        self.V_max = [0.5 * (b[1] - b[0]) for b in bounds]
        self.num_dim = num_dim

        # best position individual
        self.pos_best_i = []

        # best error individual
        self.err_best_i=-1

        # error individual
        self.err_i=-1 
    
        
        #self.pos_best_i = list(self.position_i)
        #self.err_best_i = float('inf')
        #self.err_i = float('inf')
        #self.function = function
        #self.num_dim = num_dim
        #self.V_max = [0.5 * (b[1] - b[0]) for b in bounds]


    def evaluate(self, function):
        """
        Evaluate a particle's current position, by calculating the value of its objective function.
        Update the particle's best position and error if the current position is better.

        :param function: Function to be optimized.
        """ 
        
        self.err_i = function(self.position_i)

        # check to see if the current position is an individual best
        if self.err_i < self.err_best_i or self.err_best_i==-1:
            self.pos_best_i=self.position_i
            self.err_best_i=self.err_i


    def update_velocity(self, pos_best_g, w, c1, c2, rng: np.random.RandomState):
        """
        Update particle's velocity based on constant inertia weight, cognitive constant, social constant, 
            personal best and global best. 

        :param pos_best_g: The global best position.
        :param w: Constant inertia weight (how much to weigh the previous velocity).
        :param c1: Cognitive constant.
        :param c2: Social constant.
        
        """ 
        

        for i in range(0,self.num_dim):
            r1 = rng.random()
            r2 = rng.random()

            vel_cognitive= c1* r1 *(self.pos_best_i[i] - self.position_i[i])
            vel_social= c2 * r2 * (pos_best_g[i] - self.position_i[i])
            
            velocity = w * self.velocity_i[i] + vel_cognitive + vel_social

            # Clamp Velocity using V_max
            if velocity > self.V_max[i]:
                velocity = self.V_max[i]
                
            if velocity < -self.V_max[i]:
                velocity = -self.V_max[i]
                
            self.velocity_i[i] = velocity

    def update_position(self, bounds):
        """
        Update particle's position based on current velocity and current position.

        :param bounds: List of bounds for each dimension.
        """ 
        
        for i in range(0, self.num_dim):
            
            self.position_i[i] = self.position_i[i] + self.velocity_i[i]

            # adjust maximum position if necessary
            if self.position_i[i ]> bounds[i][1]:
                self.position_i[i] = bounds[i][1]

            # adjust minimum position if necessary
            if self.position_i[i] < bounds[i][0]:
                self.position_i[i] = bounds[i][0]

class PSO_ND():
    """
    Implement PSO (Particle Swarm Optimization) algorithm.
    """
    def __init__(self, num_dim, function, bounds, swarm_size, maxiter, w, c1, c2, early_stop_threshold, k_clusters, exp_coef = 1, contr_coef = 0.5, rng = None):
        """
        Initialize PSO and swarm of particles.

        :param num_dim: Number of dimensions.
        :param function: Function to be optimized.
        :param bounds: List of bounds for each particle dimension.
        :param swarm_size: Number of particles in swarm.
        :param maxiter: Maximum number of iterations.
        :param w: Constant inertia weight (how much to weigh the previous velocity).
        :param c1: Cognitive constant.
        :param c2: Social constant.
        :param early_stop_threshold: Stop when min of function below a tiny threshold.
        """
        if rng is None:
            rng = np.random.RandomState()
        
        self.num_dim = num_dim
        self.function = function
        self.swarm_size = swarm_size
        self.maxiter = maxiter
        self.w = w
        self.c1 = c1
        self.c2 = c2
        
        self.bounds = bounds

        self.swarm = [Particle_ND(bounds, num_dim, rng) for _ in range(swarm_size)]
        
        self.pos_best_g = []
        self.err_best_g = -1

        self.early_stop_threshold = early_stop_threshold
        
        self.err_best_g_history = []
        
        self.iterations = 0
        
        self.pbest_history = [[] for _ in range(self.swarm_size)] 
        self.k_clusters = k_clusters
        
        self.clusters = [[] for _ in range(self.k_clusters)]
        self.exp_coef = exp_coef
        self.contr_coef = contr_coef
        
    def assign_clusters(self):
        """
        Assigns particles to clusters.
        """
        distance_matrix = np.zeros((self.swarm_size, self.k_clusters))
        for i in range(0,self.swarm_size):
            for k in range(self.k_clusters):
                distance_matrix[i, k] = np.linalg.norm(np.array(self.swarm[i].position_i) - np.array(self.cluster_centers[k]))
            
        self.clusters = np.argmin(distance_matrix, axis=1)


    def nelder_mead(self, flips, do_Kmeans, rng):
        """
        Applies Nedler Mead to each cluster.
        """
        evals = []
        new_centroids = [] 
        
        
        if do_Kmeans is False:
            points_per_cluster = self.num_dim + 1  

            all_indices = list(range(self.swarm_size))
            rng.shuffle(all_indices)

            clusters = []
            for i in range(self.k_clusters):
                cluster_indices = all_indices[i*points_per_cluster : (i+1)*points_per_cluster]
                clusters.append(cluster_indices)
            
            self.clusters = clusters
        

        for k in range(self.k_clusters):
            # indices of positions assigned to this cluster
            #cluster_indices = np.where(self.clusters == k)[0]
            #print("Cluster indices:", cluster_indices)
            if do_Kmeans is True:
                cluster_points = [self.swarm[i] for i in range(self.swarm_size) if self.clusters[i] == k]
            else:
                for cluster_points_indices in clusters:
                    cluster_points = [self.swarm[i] for i in cluster_points_indices]
                
            if len(cluster_points) <= self.num_dim:
               continue
            
            
            for i in range(flips):
                cluster_points = sorted(cluster_points, key=lambda p: p.err_i)
                cluster_points = cluster_points[:self.num_dim + 1]

                positions = np.array([p.position_i for p in cluster_points])

                evals = np.array([p.err_i for p in cluster_points])

                # Identify worst point (highest eval)
                worst_idx = np.argmax(evals)
                worst_particle = cluster_points[worst_idx]
                worst_position = positions[worst_idx]
                worst_eval = evals[worst_idx]

                # Compute centroid of all points except the worst
                others = np.delete(positions, worst_idx, axis=0)
                centroid = np.mean(others, axis=0)
                best = np.min(others)

                # Reflection
                R = centroid + (centroid - worst_position)

                for i in range(0, self.num_dim):
                    # adjust maximum position if necessary
                    if R[i]> self.bounds[i][1]:
                        R[i] = self.bounds[i][1]
            
                    # adjust minimum position if necessary
                    if R[i] < self.bounds[i][0]:
                        R[i] = self.bounds[i][0]
                
                
                fR = self.function(R)
            
                # Expansion
                if fR < best:
                    Re = centroid + self.exp_coef * (centroid - worst_position)
                    for i in range(0, self.num_dim):
                        # adjust maximum position if necessary
                        if Re[i] > self.bounds[i][1]:
                            Re[i] = self.bounds[i][1]
                
                        # adjust minimum position if necessary
                        if Re[i] < self.bounds[i][0]:
                            Re[i] = self.bounds[i][0]
                    
                    fRe = self.function(Re)

                    if fRe < fR:
                        new_point = Re
                        new_val = fRe
                    else:
                        new_point = R
                        new_val = fR
                
                # Contraction
                elif fR > worst_eval:
                    Rc = centroid + self.contr_coef * (centroid - worst_position)
                    for i in range(0, self.num_dim):
                        # adjust maximum position if necessary
                        if Rc[i] > self.bounds[i][1]:
                            Rc[i] = self.bounds[i][1]
                
                        # adjust minimum position if necessary
                        if Rc[i] < self.bounds[i][0]:
                            Rc[i] = self.bounds[i][0]
                    fRc = self.function(Rc)
                    if fRc < fR:
                        new_point = Rc 
                        new_val = fRc
                    else:
                        new_point = R
                        new_val = fR
                
                elif worst_eval < fR < best:
                    Rc = centroid - self.contr_coef * (centroid - worst_position)
                    for i in range(0, self.num_dim):
                        # adjust maximum position if necessary
                        if Rc[i] > self.bounds[i][1]:
                            Rc = self.bounds[i][1]
                
                        # adjust minimum position if necessary
                        if Rc < self.bounds[i][0]:
                            Rc = self.bounds[i][0]
                    fRc = self.function(Rc)
                    if fRc < fR:
                        new_point = Rc
                        new_val = fRc
                    else:
                        new_point = R
                        new_val = fR
                else:
                    new_point = R
                    new_val = fR

                
                worst_particle.position_i = new_point
                worst_particle.err_i = new_val

                if new_val < self.err_best_g:
                    self.err_best_g = new_val
                    self.pos_best_g = new_point.copy()
                   

                if worst_particle.err_i < worst_particle.err_best_i:
                    worst_particle.pos_best_i=worst_particle.position_i.copy()
                    worst_particle.err_best_i=worst_particle.err_i
               
            # Save updated cluster centroid
            new_centroids.append(np.mean([p.position_i for p in cluster_points], axis=0))

        # Update global centroids
        self.cluster_centers = new_centroids 

    def run(self, rng: np.random.RandomState, do_Kmeans = True, flips = 10):
        """
        Runs Hybrid PSO.
        """
       
        # begin optimization loop
        i=0
        while i < self.maxiter:
            #print i,err_best_g
            # cycle through particles in swarm and evaluate fitness
            for j in range(0,self.swarm_size):
                self.swarm[j].evaluate(self.function)
                self.pbest_history[j].append(self.swarm[j].err_best_i)
                # determine if current particle is the best (globally)
                if self.swarm[j].err_i < self.err_best_g or self.err_best_g == -1:
                    self.pos_best_g = list(self.swarm[j].position_i)
                    self.err_best_g = float(self.swarm[j].err_i)
                    

            # cycle through swarm and update velocities and position
            for j in range(0, self.swarm_size):
                self.swarm[j].update_velocity(self.pos_best_g, self.w, self.c1, self.c2, rng)
                self.swarm[j].update_position(self.bounds)
            indices = rng.choice(len(self.swarm), size=self.k_clusters, replace=False)
            self.cluster_centers = [self.swarm[i].position_i.copy() for i in indices]
            if do_Kmeans is True:
                for j in range(10):
                    
                    self.assign_clusters() # Assign Cluster (10 steps per PSO Iteration like in the paper)
                
            
            self.nelder_mead(flips, do_Kmeans, rng) # Apply Nelder-Mead simplex per cluster
            self.err_best_g_history.append(self.err_best_g)
            i+=1
            if self.err_best_g < self.early_stop_threshold:
                break

    
        self.iterations = i

# %%
def run_pso(seed, bounds, n_dim, swarm_size, max_iter, 
                        w, c1, c2, 
                        threshold, k_clusters, function, exp_coef, contr_coef, flips, do_Kmeans):
    """
    Runs a PSO instance with a given random seed. 
    Used for parallel execution.

    :param pso: PSO instance.
    :param seed: Seed for random generator for ensuring reproducibility.
    
    :return: PSO instance after execution.
    """
    rng = np.random.RandomState(seed)

    pso = PSO_ND(num_dim = n_dim, function = function, bounds = bounds,
                    swarm_size = swarm_size, maxiter = max_iter,
                    w = w, c1 = c1, c2 = c2,
                    early_stop_threshold=threshold,
                    k_clusters = k_clusters, exp_coef = exp_coef, contr_coef = contr_coef, rng = rng)

    
    pso.run(rng, do_Kmeans, flips)
    return pso

# %% [markdown]
# # Sphere Optimization

# %% [markdown]
# ## Sphere: 2 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 2, function = sphere, exp_coef = 0.5, contr_coef = 0.1, 
                        flips = 2, do_Kmeans = False):

    
    bounds = [(-5.12, 5.12)] * n_dim  


    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Sphere over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Sphere over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Sphere Optimization in 2 Dimensions with Random Clusters:\n\n\n")
all_runs_2D = run_pso_experiments(n_dim=2, function=sphere, do_Kmeans=False)


print("\n\n\nSphere Optimization in 2 Dimensions with KMeans Clustering:\n\n\n")
all_runs_2D_k_mean = run_pso_experiments(n_dim=2, function=sphere, do_Kmeans=True)
# Out:
# Sphere Optimization in 2 Dimensions with Random Clusters:
#
#
#
# Final fitness stats for 2D Sphere over 30 runs:
# Mean: 5.0e-09
# Median: 4.6e-09
# Best: 1.4e-10
# Worst: 9.9e-09
# Std Dev: 3.0e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Sphere over 30 runs:
# Max iterations: 64
# Min iterations 41
# Mean iterations 55.53333333333333
#
#
#
# Sphere Optimization in 2 Dimensions with KMeans Clustering:
#
#
#
# Final fitness stats for 2D Sphere over 30 runs:
# Mean: 5.0e-09
# Median: 4.6e-09
# Best: 3.6e-11
# Worst: 1.0e-08
# Std Dev: 2.5e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Sphere over 30 runs:
# Max iterations: 80
# Min iterations 43
# Mean iterations 67.0

# %% [markdown]
# ## Sphere: 10 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt


def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 2, function = sphere, flips = 12, exp_coef = 0.5, contr_coef = 0.1,
                        do_Kmeans = False):

    
    bounds = [(-5.12, 5.12)] * n_dim  


    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Sphere over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Sphere over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Sphere Optimization in 10 Dimensions with Random Clusters:\n\n\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=sphere, max_iter=500)


print("\n\n\nSphere Optimization in 10 Dimensions with KMeans Clustering:\n\n\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=sphere, do_Kmeans=True, max_iter=500)
# Out:
# Sphere Optimization in 10 Dimensions with Random Clusters:
#
#
#
# Final fitness stats for 10D Sphere over 30 runs:
# Mean: 7.3e-09
# Median: 7.5e-09
# Best: 1.4e-09
# Worst: 1.0e-08
# Std Dev: 2.0e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 10 Sphere over 30 runs:
# Max iterations: 100
# Min iterations 81
# Mean iterations 91.2
#
#
#
# Sphere Optimization in 10 Dimensions with KMeans Clustering:
#
#
#
# Final fitness stats for 10D Sphere over 30 runs:
# Mean: 8.1e-09
# Median: 8.6e-09
# Best: 3.5e-09
# Worst: 9.9e-09
# Std Dev: 1.5e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 10 Sphere over 30 runs:
# Max iterations: 133
# Min iterations 99
# Mean iterations 114.86666666666666

# %% [markdown]
# ## Sphere: 30 dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Random K Means

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 1, function = sphere, exp_coef = 0.5, contr_coef = 0.1,
                        flips = 12, do_Kmeans = True):

    
    bounds = [(-5.12, 5.12)] * n_dim  


    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):

            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Sphere over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Sphere over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Sphere Optimization in 30 Dimensions with Random Clusters:\n")
all_runs_30D = run_pso_experiments(n_dim=30, swarm_size = 50, function=sphere, max_iter = 1000, do_Kmeans=False)


print("\n\n\nSphere Optimization in 30 Dimensions with KMeans Clustering:\n")
all_runs_30D = run_pso_experiments(n_dim=30, swarm_size = 50, function=sphere, max_iter = 1000, do_Kmeans=True)
# Out:
# Sphere Optimization in 30 Dimensions with Random Clusters:
#
# Final fitness stats for 30D Sphere over 30 runs:
# Mean: 9.1e-09
# Median: 9.2e-09
# Best: 6.4e-09
# Worst: 1.0e-08
# Std Dev: 7.7e-10
# Success Rate: 1.0 (100.0%)
# Number of iterations for 30 Sphere over 30 runs:
# Max iterations: 482
# Min iterations 333
# Mean iterations 406.5
#
#
#
# Sphere Optimization in 30 Dimensions with KMeans Clustering:
#
# Final fitness stats for 30D Sphere over 30 runs:
# Mean: 9.3e-09
# Median: 9.3e-09
# Best: 7.8e-09
# Worst: 1.0e-08
# Std Dev: 5.8e-10
# Success Rate: 1.0 (100.0%)
# Number of iterations for 30 Sphere over 30 runs:
# Max iterations: 505
# Min iterations 275
# Mean iterations 357.8

# %% [markdown]
# # Rosenbrock Optimization

# %% [markdown]
# ## Rosenbrock: 2 dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 2, function = rosenbrock, exp_coef = 0.5, contr_coef = 0.1, flips = 2, do_Kmeans = True):

    
    bounds = [(-5.0, 10.0)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rosenbrock over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rosenbrock over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Rosenbrock Optimization in 2 Dimensions with Random Clusters:\n")
all_runs_2D = run_pso_experiments(n_dim=2, function=rosenbrock, do_Kmeans=False)

print("\n\n\nRosenbrock Optimization in 2 Dimensions with KMeans Clustering:\n")
all_runs_2D = run_pso_experiments(n_dim=2, function=rosenbrock, do_Kmeans = True)
# Out:
# Rosenbrock Optimization in 2 Dimensions with Random Clusters:
#
# Final fitness stats for 2D Rosenbrock over 30 runs:
# Mean: 5.6e-09
# Median: 6.4e-09
# Best: 4.2e-10
# Worst: 9.7e-09
# Std Dev: 2.9e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Rosenbrock over 30 runs:
# Max iterations: 186
# Min iterations 88
# Mean iterations 112.8
#
#
#
# Rosenbrock Optimization in 2 Dimensions with KMeans Clustering:
#
# Final fitness stats for 2D Rosenbrock over 30 runs:
# Mean: 5.0e-09
# Median: 4.4e-09
# Best: 6.6e-10
# Worst: 9.9e-09
# Std Dev: 2.7e-09
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Rosenbrock over 30 runs:
# Max iterations: 182
# Min iterations 88
# Mean iterations 129.83333333333334

# %% [markdown]
# ## Rosenbrock: 10 dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
n_runs = 30

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 2, function = rosenbrock, exp_coef = 0.5, contr_coef = 0.1, flips = 12, do_Kmeans = False):

    
    bounds = [(-5.0, 10.0)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))

            
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rosenbrock over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rosenbrock over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Rosenbrock Optimization in 10 Dimensions with Random Clusters:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, max_iter = 500, do_Kmeans=False)

print("\n\n\nRosenbrock Optimization in 10 Dimensions with KMeans Clustering:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, do_Kmeans = True, max_iter = 500)
# Out:
# Rosenbrock Optimization in 10 Dimensions with Random Clusters:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 3.7e+00
# Median: 1.8e-03
# Best: 2.5e-05
# Worst: 9.5e+01
# Std Dev: 1.7e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0
#
#
#
# Rosenbrock Optimization in 10 Dimensions with KMeans Clustering:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 1.3e+02
# Median: 5.8e-02
# Best: 1.9e-04
# Worst: 2.5e+03
# Std Dev: 4.8e+02
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0

# %%
print("Rosenbrock Optimization in 10 Dimensions with Random Clusters:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, max_iter = 500, do_Kmeans=False, flips = 20)

print("\n\n\nRosenbrock Optimization in 10 Dimensions with KMeans Clustering:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, do_Kmeans = True, max_iter = 500, flips = 20)
# Out:
# Rosenbrock Optimization in 10 Dimensions with Random Clusters:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 1.1e+01
# Median: 1.4e-05
# Best: 4.4e-08
# Worst: 3.0e+02
# Std Dev: 5.5e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0
#
#
#
# Rosenbrock Optimization in 10 Dimensions with KMeans Clustering:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 9.5e-01
# Median: 1.5e-02
# Best: 4.4e-04
# Worst: 4.0e+00
# Std Dev: 1.7e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0

# %%
print("Rosenbrock Optimization in 10 Dimensions with Random Clusters:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, max_iter = 1000, do_Kmeans=False, flips = 20)

print("\n\n\nRosenbrock Optimization in 10 Dimensions with KMeans Clustering:\n")
all_runs_10D = run_pso_experiments(n_dim=10, function=rosenbrock, do_Kmeans = True, max_iter = 1000, flips = 20)
# Out:
# Rosenbrock Optimization in 10 Dimensions with Random Clusters:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 1.1e+01
# Median: 9.9e-09
# Best: 7.4e-09
# Worst: 3.0e+02
# Std Dev: 5.5e+01
# Success Rate: 0.7333333333333333 (73.33333333333333%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 1000
# Min iterations 564
# Mean iterations 784.6333333333333
#
#
#
# Rosenbrock Optimization in 10 Dimensions with KMeans Clustering:
#
# Final fitness stats for 10D Rosenbrock over 30 runs:
# Mean: 9.3e-01
# Median: 7.9e-05
# Best: 1.6e-06
# Worst: 4.0e+00
# Std Dev: 1.7e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rosenbrock over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %% [markdown]
# ## Rosenbrock: 30 dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-8, k_clusters = 1, function = rosenbrock, exp_coef = 0.5, contr_coef = 0.1, flips = 12, do_Kmeans = False):

    
    bounds = [(-5.0, 10.0)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rosenbrock over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rosenbrock over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Rosenbrock Optimization in 30 Dimensions with Random Clusters:\n")
all_runs_30D = run_pso_experiments(n_dim=30, swarm_size = 50, function=rosenbrock, max_iter = 1000, k_clusters = 1, do_Kmeans=False)

print("\n\n\nRosenbrock Optimization in 30 Dimensions with KMeans Clustering:\n")
all_runs_30D = run_pso_experiments(n_dim=30, swarm_size = 50, function=rosenbrock, do_Kmeans = True, max_iter = 1000, k_clusters = 1)
# Out:
# Rosenbrock Optimization in 30 Dimensions with Random Clusters:
#
# Final fitness stats for 30D Rosenbrock over 30 runs:
# Mean: 9.3e+03
# Median: 2.0e+01
# Best: 7.4e-02
# Worst: 1.1e+05
# Std Dev: 2.9e+04
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Rosenbrock over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0
#
#
#
# Rosenbrock Optimization in 30 Dimensions with KMeans Clustering:
#
# Final fitness stats for 30D Rosenbrock over 30 runs:
# Mean: 1.6e+04
# Median: 2.1e+01
# Best: 5.4e+00
# Worst: 1.7e+05
# Std Dev: 3.5e+04
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Rosenbrock over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %% [markdown]
# # Rastigrin Optimization

# %% [markdown]
# ## Rastigrin: 2 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 2, function = rastigrin, flips = 2, do_Kmeans = False,
                        exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-5.12, 5.12)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rastigrin over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rastigrin over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Rastigrin(2 Dimensions) Using Random Clusters:\n")
all_runs_2D = run_pso_experiments(n_dim = 2, function = rastigrin, do_Kmeans=False)

print("\n\nOptimize Rastigrin(2 Dimensions) Using KMeans Clustering Clusters:\n")
all_runs_2D = run_pso_experiments(n_dim = 2, function = rastigrin, do_Kmeans = True)
# Out:
# Optimize Rastigrin(2 Dimensions) Using Random Clusters:
#
# Final fitness stats for 2D Rastigrin over 30 runs:
# Mean: 1.7e-01
# Median: 5.7e-05
# Best: 7.3e-06
# Worst: 9.9e-01
# Std Dev: 3.7e-01
# Success Rate: 0.8333333333333334 (83.33333333333334%)
# Number of iterations for 2 Rastigrin over 30 runs:
# Max iterations: 300
# Min iterations 33
# Mean iterations 93.43333333333334
#
#
# Optimize Rastigrin(2 Dimensions) Using KMeans Clustering Clusters:
#
# Final fitness stats for 2D Rastigrin over 30 runs:
# Mean: 6.6e-02
# Median: 5.1e-05
# Best: 2.7e-07
# Worst: 9.9e-01
# Std Dev: 2.5e-01
# Success Rate: 0.9333333333333333 (93.33333333333333%)
# Number of iterations for 2 Rastigrin over 30 runs:
# Max iterations: 300
# Min iterations 34
# Mean iterations 76.23333333333333

# %% [markdown]
# ## Rastigrin: 10 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 2, function = rastigrin, flips = 12, do_Kmeans = False, 
                        exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-5.12, 5.12)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rastigrin over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rastigrin over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Rastigrin(10 Dimensions) Using Random Clusters:\n")
all_runs_10D = run_pso_experiments(n_dim = 10, function = rastigrin, max_iter = 500, do_Kmeans=False)

print("\n\nOptimize Rastigrin(10 Dimensions) Using KMeans Clustering Clusters:\n")
all_runs_10D = run_pso_experiments(n_dim = 10, function = rastigrin, do_Kmeans = True, max_iter = 500)
# Out:
# Optimize Rastigrin(10 Dimensions) Using Random Clusters:
#
# Final fitness stats for 10D Rastigrin over 30 runs:
# Mean: 1.8e+01
# Median: 1.6e+01
# Best: 5.0e+00
# Worst: 4.7e+01
# Std Dev: 8.9e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rastigrin over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0
#
#
# Optimize Rastigrin(10 Dimensions) Using KMeans Clustering Clusters:
#
# Final fitness stats for 10D Rastigrin over 30 runs:
# Mean: 1.8e+01
# Median: 1.6e+01
# Best: 6.0e+00
# Worst: 4.0e+01
# Std Dev: 9.0e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 10 Rastigrin over 30 runs:
# Max iterations: 500
# Min iterations 500
# Mean iterations 500.0

# %% [markdown]
# ## Rastigrin: 30 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 1, function = rastigrin, flips = 12, do_Kmeans = False,
                        exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-5.12, 5.12)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Rastigrin over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Rastigrin over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Rastigrin(30 Dimensions) Using Random Clusters:\n")
all_runs_2D = run_pso_experiments(n_dim = 30, swarm_size = 50, function = rastigrin, max_iter = 1000, k_clusters = 1, do_Kmeans = False)

print("\n\nOptimize Rastigrin(30 Dimensions) Using KMeans Clustering Clusters:\n")
all_runs_30D = run_pso_experiments(n_dim = 30, swarm_size = 50 , function = rastigrin, do_Kmeans = True, max_iter = 1000, k_clusters = 1)
# Out:
# Optimize Rastigrin(30 Dimensions) Using Random Clusters:
#
# Final fitness stats for 30D Rastigrin over 30 runs:
# Mean: 1.1e+02
# Median: 1.1e+02
# Best: 6.6e+01
# Worst: 1.7e+02
# Std Dev: 2.6e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Rastigrin over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0
#
#
# Optimize Rastigrin(30 Dimensions) Using KMeans Clustering Clusters:
#
# Final fitness stats for 30D Rastigrin over 30 runs:
# Mean: 9.7e+01
# Median: 9.3e+01
# Best: 3.9e+01
# Worst: 1.7e+02
# Std Dev: 2.9e+01
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Rastigrin over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %% [markdown]
# # Ackley Optimization

# %% [markdown]
# ## Ackley: 2 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 2, function = ackley, flips = 2, do_Kmeans = False, exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-32.786, 32.786)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Ackley over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Ackley over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Ackley in 2 dimensions with Random Clusters:")
all_runs_2D = run_pso_experiments(n_dim = 2, function = ackley, do_Kmeans = False)

print("Optimize Ackley in 2 dimensions with KMeans Clustering:")
all_runs_2D = run_pso_experiments(n_dim = 2, function = ackley, do_Kmeans = True)
# Out:
# Optimize Ackley in 2 dimensions with Random Clusters:
# Final fitness stats for 2D Ackley over 30 runs:
# Mean: 6.5e-05
# Median: 6.8e-05
# Best: 9.2e-06
# Worst: 9.9e-05
# Std Dev: 2.3e-05
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Ackley over 30 runs:
# Max iterations: 96
# Min iterations 65
# Mean iterations 76.7
# Optimize Ackley in 2 dimensions with KMeans Clustering:
# Final fitness stats for 2D Ackley over 30 runs:
# Mean: 7.1e-05
# Median: 7.3e-05
# Best: 2.6e-05
# Worst: 9.9e-05
# Std Dev: 2.1e-05
# Success Rate: 1.0 (100.0%)
# Number of iterations for 2 Ackley over 30 runs:
# Max iterations: 118
# Min iterations 77
# Mean iterations 94.4

# %% [markdown]
# ## Ackley: 10 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 2, function = ackley, flips = 12, do_Kmeans = False,
                        exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-32.786, 32.786)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Ackley over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Ackley over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Ackley in 10 dimensions with Random Clusters:")
all_runs_10D = run_pso_experiments(n_dim = 10, function = ackley, max_iter = 500)

print("Optimize Ackley in 10 dimensions with KMeans Clustering:")
all_runs_10D = run_pso_experiments(n_dim = 10, function = ackley, do_Kmeans = True, max_iter = 500)
# Out:
# Optimize Ackley in 10 dimensions with Random Clusters:
# Final fitness stats for 10D Ackley over 30 runs:
# Mean: 6.2e-01
# Median: 9.7e-05
# Best: 6.3e-05
# Worst: 2.8e+00
# Std Dev: 8.3e-01
# Success Rate: 0.6 (60.0%)
# Number of iterations for 10 Ackley over 30 runs:
# Max iterations: 500
# Min iterations 99
# Mean iterations 265.3666666666667
# Optimize Ackley in 10 dimensions with KMeans Clustering:
# Final fitness stats for 10D Ackley over 30 runs:
# Mean: 8.3e-01
# Median: 1.2e+00
# Best: 6.7e-05
# Worst: 3.2e+00
# Std Dev: 8.8e-01
# Success Rate: 0.4666666666666667 (46.666666666666664%)
# Number of iterations for 10 Ackley over 30 runs:
# Max iterations: 500
# Min iterations 117
# Mean iterations 332.26666666666665

# %% [markdown]
# ## Ackley: 30 Dimensions

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def run_pso_experiments(n_dim = 2, swarm_size = 30, max_iter = 300, 
                        w = 0.7, c1 = 1.5, c2 = 1.5, n_runs = 30, 
                        threshold = 1e-4, k_clusters = 1,  function = ackley, flips = 12, do_Kmeans = False,
                        exp_coef = 0.5, contr_coef = 0.1):

    
    bounds = [(-32.786, 32.786)] * n_dim  

    all_runs = []
    results = []
    with multiprocessing.Pool(processes=pool_size) as pool:
        for run in range(n_runs):
            res = pool.apply_async(run_pso, (run, bounds, n_dim, swarm_size, max_iter, w, c1, c2, threshold, k_clusters, function, exp_coef, contr_coef, 
                                             flips, do_Kmeans,))
            results.append(res)

        for result in [res.get() for res in results]:
            run_result = {
                'final_fitness': result.err_best_g,
                'best_position': result.pos_best_g,
                'iterations': result.iterations,
                'fitness_history': result.err_best_g_history,
                'evaluations': result.iterations * swarm_size,
                'pbest_history': result.pbest_history
            }
            all_runs.append(run_result)

   # Compute Statistics for Final Fitnesses
    final_fitnesses = np.array([run['final_fitness'] for run in all_runs]) # Collect final fitnesses for each run
    mean_final_fitness = np.mean(final_fitnesses) # Mean of final fitnesses
    median_final_fitness = np.median(final_fitnesses) # Median of final fitnesses
    best_final_fitness = np.min(final_fitnesses) # Best final fitness
    worst_final_fitness = np.max(final_fitnesses) # Worst final fitness
    std_dev_final_fitness = np.std(final_fitnesses) # Standard deviation 
    success_rate_final_fitness = np.sum(final_fitnesses <= threshold)/n_runs # Success rate: Number of sucessful runs/ no. of runs
    
    # Print Statistics
    print(f"Final fitness stats for {n_dim}D Ackley over 30 runs:")
    print(f"Mean: {mean_final_fitness:.1e}")
    print(f"Median: {median_final_fitness:.1e}")
    print(f"Best: {best_final_fitness:.1e}")
    print(f"Worst: {worst_final_fitness:.1e}")
    print(f"Std Dev: {std_dev_final_fitness:.1e}")
    print(f"Success Rate: {success_rate_final_fitness} ({success_rate_final_fitness*100}%) ")
    
    # Convergence Plot for All Runs - Fitness history of all runs
    # Since early stopping is added, no. of iterations can vary between runs
    # Therefore plot each run individually
    for run in all_runs:
        plt.plot(run['fitness_history'], alpha=0.3)
    plt.xlabel('Iteration')
    plt.ylabel('Global Best Fitness')
    plt.title('Convergence Plot (30 runs)')
    plt.show()
    
    # Iterations
    
    no_iterations =  np.array([run['iterations'] for run in all_runs]) 
    min_iterations = np.min(no_iterations) # Min iterations
    max_iterations = np.max(no_iterations) # Max iterations
    mean_iterations = np.mean(no_iterations) # Mean iterations
    
    print(f"Number of iterations for {n_dim} Ackley over 30 runs:")
    print("Max iterations:", max_iterations)
    print("Min iterations", min_iterations)
    print("Mean iterations", mean_iterations)

    return all_runs

print("Optimize Ackley in 30 dimensions with Random Clusters:")
all_runs_30D = run_pso_experiments(n_dim = 30, swarm_size = 50, function = ackley, max_iter = 1000, k_clusters = 1)

print("Optimize Ackley in 30 dimensions with KMeans Clustering:")
all_runs_30D = run_pso_experiments(n_dim = 30, swarm_size = 50, function = ackley, do_Kmeans = True, max_iter = 1000, k_clusters = 1)
# Out:
# Optimize Ackley in 30 dimensions with Random Clusters:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 4.3e+00
# Median: 3.2e+00
# Best: 1.3e+00
# Worst: 1.7e+01
# Std Dev: 3.8e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Ackley over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0
# Optimize Ackley in 30 dimensions with KMeans Clustering:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 3.8e+00
# Median: 3.4e+00
# Best: 1.2e+00
# Worst: 1.5e+01
# Std Dev: 2.5e+00
# Success Rate: 0.0 (0.0%)
# Number of iterations for 30 Ackley over 30 runs:
# Max iterations: 1000
# Min iterations 1000
# Mean iterations 1000.0

# %%
print("Optimize Ackley in 30 dimensions with Random Clusters:")
all_runs_30D = run_pso_experiments(n_dim = 30, swarm_size = 50, function = ackley, max_iter = 1000, k_clusters = 1, exp_coef = 1, contr_coef=0.5)

print("Optimize Ackley in 30 dimensions with KMeans Clustering:")
all_runs_30D = run_pso_experiments(n_dim = 30, swarm_size = 50, function = ackley, do_Kmeans = True, max_iter = 1000, k_clusters = 1, exp_coef = 1, contr_coef=0.5)
# Out:
# Optimize Ackley in 30 dimensions with Random Clusters:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 3.8e+00
# Median: 2.4e+00
# Best: 9.8e-05
# Worst: 1.5e+01
# Std Dev: 3.8e+00
# Success Rate: 0.03333333333333333 (3.3333333333333335%)
# Number of iterations for 30 Ackley over 30 runs:
# Max iterations: 1000
# Min iterations 659
# Mean iterations 988.6333333333333
# Optimize Ackley in 30 dimensions with KMeans Clustering:
# Final fitness stats for 30D Ackley over 30 runs:
# Mean: 1.4e+00
# Median: 1.5e+00
# Best: 9.0e-05
# Worst: 8.0e+00
# Std Dev: 1.6e+00
# Success Rate: 0.36666666666666664 (36.666666666666664%)
# Number of iterations for 30 Ackley over 30 runs:
# Max iterations: 1000
# Min iterations 482
# Mean iterations 847.0
